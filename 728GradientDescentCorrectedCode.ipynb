# %% [markdown]
# Consider the following nonlinear function: f(x) = ($x_{1}$ + 10*$x_{2}$)**2 + 5*($x_{3}$ - $x_{4}$)**4 + 10*($x_{1}$ - $x_{4}$)**4.
# The initial guess x0 = [3;-1;0;1], step length alpha = 0.001, and the convergence threshold is set to 0.01.
#
# Modify the in-class code to preform the gradient descent method. Also will need to state the iterations and the final x values at convergence.

# %%
# import the libraries
import numpy as np
import math

# %%
## a function returns the Gradient vector at the input vector x_i
## note: the expression of each element in the Gradient vector is hard-coded based on the formula presented above, which is also given on Slide 40 of Topic 3.1

#this part is modified for our function when using partial derivatives of each x1-4. g[0] corresponds to our partial derivative of x1, and etc
def getGradientVector(x_i):
  g = np.zeros((4,1))   #(amount of x_i, 1)
  g[0] = 2 * (x_i[0] + 10*x_i[1]) + 40 * (x_i[0] - x_i[3]) ** 3
  g[1] = 20 * (x_i[0] + 10*x_i[1]) + 4 * (x_i[1] - 2*x_i[2]) ** 3
  g[2] = 10 * (x_i[2] - x_i[3]) - 8 * (x_i[1] - 2*x_i[2]) ** 3
  g[3] = -10 * (x_i[2] - x_i[3]) - 40 * (x_i[0] - x_i[3]) ** 3
  return g

# a simple function returns the norm of an input vector
def getNorm(v):
  return math.sqrt(v[0]*v[0] + v[1]*v[1] + v[2]*v[2] + v[3]*v[3])   #v[x_i]*v[x_i]

# %%
## set an initial guess
x_0 = np.array([[3.0], [-1.0], [0.0], [1.0]]) #we got this initial guess given in the problem
print(f"--The initial guess x0: ")
print(x_0)

## set a threshold value for getting a good solution (given in problem)
thresh = 0.01

## set step length (given in problem)
alpha = 0.001


#this whole part and onward is not edited 
x_i = x_0
count = 0
while True:
  print('****************************************************')
  print(f'--At iteration: {count}')
  
  ## compute the gradient vector at x_i
  g = getGradientVector(x_i)
  print(f"--The gradient vector g(x_{count}): ")
  print(g)

  ## compute the norm of the gradient vector at x_i
  normOfGradient = getNorm(g)
  print(f"--The norm of the gradient vector |g(x_{count})|: {normOfGradient}")

  ## check if converged; if true, then stop; continue otherwise
  if normOfGradient <= thresh:
    break


  ## get h=-g
  h_i = -1*g
  print(f"--The h vector h_{count}: ")
  print(h_i)

  ## get the new solution point
  x_i_plus1 = x_i + alpha * h_i
  print(f"--The solution vector x_{count+1}: ")
  print(x_i_plus1)

  x_i = x_i_plus1
  count = count + 1
  print()
# Out:
# --The initial guess x0:
# [[ 3.]
#  [-1.]
#  [ 0.]
#  [ 1.]]
# ****************************************************
# --At iteration: 0
# --The gradient vector g(x_0):
# [[ 306.]
#  [-144.]
#  [  -2.]
#  [-310.]]
# --The norm of the gradient vector |g(x_0)|: 458.77663410422286
# --The h vector h_0:
# [[-306.]
#  [ 144.]
#  [   2.]
#  [ 310.]]
# --The solution vector x_1:
# [[ 2.694e+00]
#  [-8.560e-01]
#  [ 2.000e-03]
#  [ 1.310e+00]]
#
# ****************************************************
# --At iteration: 1
# --The gradient vector g(x_1):
# [[  94.30764416]
#  [-119.864224  ]
#  [  -7.991552  ]
#  [ -92.95964416]]
# --The norm of the gradient vector |g(x_1)|: 178.79240556537596
# --The h vector h_1:
# [[-94.30764416]
#  [119.864224  ]
#  [  7.991552  ]
#  [ 92.95964416]]
# --The solution vector x_2:
# [[ 2.59969236]
#  [-0.73613578]
#  [ 0.00999155]
#  [ 1.40295964]]
#
# ****************************************************
# --At iteration: 2
# --The gradient vector g(x_2):
# [[ 59.0336176 ]
#  [-96.96244841]
#  [-10.47140028]
#  [-54.62726749]]
# --The norm of the gradient vector |g(x_2)|: 126.41389553584158
# --The h vector h_2:
# [[-59.0336176 ]
#  [ 96.96244841]
#  [ 10.47140028]
#  [ 54.62726749]]
# --The solution vector x_3:
# [[ 2.54065874]
#  [-0.63917333]
#  [ 0.02046295]
#  [ 1.45758691]]
#
# ****************************************************
# --At iteration: 3
# --The gradient vector g(x_3):
# [[ 43.11751243]
#  [-78.27976945]
#  [-11.85468219]
#  [-36.44842191]]
# --The norm of the gradient vector |g(x_3)|: 97.24126250523999
# --The h vector h_3:
# [[-43.11751243]
#  [ 78.27976945]
#  [ 11.85468219]
#  [ 36.44842191]]
# --The solution vector x_4:
# [[ 2.49754123]
#  [-0.56089356]
#  [ 0.03231763]
#  [ 1.49403533]]
#
# ****************************************************
# --At iteration: 4
# --The gradient vector g(x_4):
# [[ 34.19939504]
#  [-63.20693059]
#  [-12.65909004]
#  [-25.80500676]]
# --The norm of the gradient vector |g(x_4)|: 77.40068235780772
# --The h vector h_4:
# [[-34.19939504]
#  [ 63.20693059]
#  [ 12.65909004]
#  [ 25.80500676]]
# --The solution vector x_5:
# [[ 2.46334183]
#  [-0.49768663]
#  [ 0.04497672]
#  [ 1.51984034]]
#
# ****************************************************
# --At iteration: 5
# --The gradient vector g(x_5):
# [[ 28.56896584]
#  [-51.0821864 ]
#  [-13.12524115]
#  [-18.84737857]]
# --The norm of the gradient vector |g(x_5)|: 62.873453944766425
# --The h vector h_5:
# [[-28.56896584]
#  [ 51.0821864 ]
#  [ 13.12524115]
#  [ 18.84737857]]
# --The solution vector x_6:
# [[ 2.43477286]
#  [-0.44660444]
#  [ 0.05810197]
#  [ 1.53868772]]
#
# ****************************************************
# --At iteration: 6
# --The gradient vector g(x_6):
# [[ 24.71858592]
#  [-41.33851649]
#  [-13.37968642]
#  [-13.97527148]]
# --The norm of the gradient vector |g(x_6)|: 51.905738188813785
# --The h vector h_6:
# [[-24.71858592]
#  [ 41.33851649]
#  [ 13.37968642]
#  [ 13.97527148]]
# --The solution vector x_7:
# [[ 2.41005428]
#  [-0.40526592]
#  [ 0.07148165]
#  [ 1.55266299]]
#
# ****************************************************
# --At iteration: 7
# --The gradient vector g(x_7):
# [[ 21.92620332]
#  [-33.51119213]
#  [-13.49362784]
#  [-10.39959987]]
# --The norm of the gradient vector |g(x_7)|: 43.519973108638915
# --The h vector h_7:
# [[-21.92620332]
#  [ 33.51119213]
#  [ 13.49362784]
#  [ 10.39959987]]
# --The solution vector x_8:
# [[ 2.38812808]
#  [-0.37175473]
#  [ 0.08497528]
#  [ 1.56306259]]
#
# ****************************************************
# --At iteration: 8
# --The gradient vector g(x_8):
# [[ 19.80713545]
#  [-27.22422702]
#  [-13.50918906]
#  [ -7.68510085]]
# --The norm of the gradient vector |g(x_8)|: 37.081533347243344
# --The h vector h_8:
# [[-19.80713545]
#  [ 27.22422702]
#  [ 13.50918906]
#  [  7.68510085]]
# --The solution vector x_9:
# [[ 2.36832094]
#  [-0.34453051]
#  [ 0.09848447]
#  [ 1.57074769]]
#
# ****************************************************
# --At iteration: 9
# --The gradient vector g(x_9):
# [[ 18.14022209]
#  [-22.17479973]
#  [-13.45239735]
#  [ -5.5715581 ]]
# --The norm of the gradient vector |g(x_9)|: 32.13718492410715
# --The h vector h_9:
# [[-18.14022209]
#  [ 22.17479973]
#  [ 13.45239735]
#  [  5.5715581 ]]
# --The solution vector x_10:
# [[ 2.35018072]
#  [-0.32235571]
#  [ 0.11193687]
#  [ 1.57631925]]
#
# ****************************************************
# --At iteration: 10
# --The gradient vector g(x_10):
# [[ 16.79068319]
#  [-18.11943327]
#  [-13.34001087]
#  [ -3.89361204]]
# --The norm of the gradient vector |g(x_10)|: 28.34355321467946
# --The h vector h_10:
# [[-16.79068319]
#  [ 18.11943327]
#  [ 13.34001087]
#  [  3.89361204]]
# --The solution vector x_11:
# [[ 2.33339003]
#  [-0.30423627]
#  [ 0.12527688]
#  [ 1.58021286]]
#
# ****************************************************
# --At iteration: 11
# --The gradient vector g(x_11):
# [[ 15.67242363]
#  [-14.86249347]
#  [-13.1832805 ]
#  [ -2.54100917]]
# --The norm of the gradient vector |g(x_11)|: 25.43175548406
# --The h vector h_11:
# [[-15.67242363]
#  [ 14.86249347]
#  [ 13.1832805 ]
#  [  2.54100917]]
# --The solution vector x_12:
# [[ 2.31771761]
#  [-0.28937378]
#  [ 0.13846016]
#  [ 1.58275387]]
#
# ****************************************************
# --At iteration: 12
# --The gradient vector g(x_12):
# [[ 14.72822419]
#  [-12.24682073]
#  [-12.99010283]
#  [ -1.43732742]]
# --The norm of the gradient vector |g(x_12)|: 23.188658595017024
# --The h vector h_12:
# [[-14.72822419]
#  [ 12.24682073]
#  [ 12.99010283]
#  [  1.43732742]]
# --The solution vector x_13:
# [[ 2.30298939]
#  [-0.27712696]
#  [ 0.15145026]
#  [ 1.5841912 ]]
#
# ****************************************************
# --At iteration: 13
# --The gradient vector g(x_13):
# [[ 13.91872209]
#  [-10.14616285]
#  [-12.76629151]
#  [ -0.52787311]]
# --The norm of the gradient vector |g(x_13)|: 21.446032130204753
# --The h vector h_13:
# [[-13.91872209]
#  [ 10.14616285]
#  [ 12.76629151]
#  [  0.52787311]]
# --The solution vector x_14:
# [[ 2.28907067]
#  [-0.2669808 ]
#  [ 0.16421655]
#  [ 1.58471907]]
#
# ****************************************************
# --At iteration: 14
# --The gradient vector g(x_14):
# [[ 13.21599311]
#  [ -8.45908488]
#  [-12.516347  ]
#  [  0.2275575 ]]
# --The norm of the gradient vector |g(x_14)|: 20.073099302009222
# --The h vector h_14:
# [[-13.21599311]
#  [  8.45908488]
#  [ 12.516347  ]
#  [ -0.2275575 ]]
# --The solution vector x_15:
# [[ 2.27585467]
#  [-0.25852171]
#  [ 0.1767329 ]
#  [ 1.58449151]]
#
# ****************************************************
# --At iteration: 15
# --The gradient vector g(x_15):
# [[ 12.59966907]
#  [ -7.10407625]
#  [-12.243931  ]
#  [  0.85919221]]
# --The norm of the gradient vector |g(x_15)|: 18.97028248440742
# --The h vector h_15:
# [[-12.59966907]
#  [  7.10407625]
#  [ 12.243931  ]
#  [ -0.85919221]]
# --The solution vector x_16:
# [[ 2.263255  ]
#  [-0.25141763]
#  [ 0.18897683]
#  [ 1.58363232]]
#
# ****************************************************
# --At iteration: 16
# --The gradient vector g(x_16):
# [[ 12.05451229]
#  [ -6.0156234 ]
#  [-11.95216174]
#  [  1.39019994]]
# --The norm of the gradient vector |g(x_16)|: 18.06338333538229
# --The h vector h_16:
# [[-12.05451229]
#  [  6.0156234 ]
#  [ 11.95216174]
#  [ -1.39019994]]
# --The solution vector x_17:
# [[ 2.25120049]
#  [-0.24540201]
#  [ 0.20092899]
#  [ 1.58224212]]
#
# ****************************************************
# --At iteration: 17
# --The gradient vector g(x_17):
# [[ 11.56885739]
#  [ -5.14105902]
#  [-11.643798  ]
#  [  1.83863467]]
# --The norm of the gradient vector |g(x_17)|: 17.29819523545082
# --The h vector h_17:
# [[-11.56885739]
#  [  5.14105902]
#  [ 11.643798  ]
#  [ -1.83863467]]
# --The solution vector x_18:
# [[ 2.23963163]
#  [-0.24026095]
#  [ 0.21257279]
#  [ 1.58040349]]
#
# ****************************************************
# --At iteration: 18
# --The gradient vector g(x_18):
# [[ 11.13358507]
#  [ -4.43803488]
#  [-11.32135265]
#  [  2.21876612]]
# --The norm of the gradient vector |g(x_18)|: 16.635769265742745
# --The h vector h_18:
# [[-11.13358507]
#  [  4.43803488]
#  [ 11.32135265]
#  [ -2.21876612]]
# --The solution vector x_19:
# [[ 2.22849805]
#  [-0.23582292]
#  [ 0.22389414]
#  [ 1.57818472]]
#
# ****************************************************
# --At iteration: 19
# --The gradient vector g(x_19):
# [[ 10.74143113]
#  [ -3.87249488]
#  [-10.9871609 ]
#  [  2.54201241]]
# --The norm of the gradient vector |g(x_19)|: 16.0484918631616
# --The h vector h_19:
# [[-10.74143113]
#  [  3.87249488]
#  [ 10.9871609 ]
#  [ -2.54201241]]
# --The solution vector x_20:
# [[ 2.21775662]
#  [-0.23195042]
#  [ 0.2348813 ]
#  [ 1.57564271]]
#
# ****************************************************
# --At iteration: 20
# --The gradient vector g(x_20):
# [[ 10.38651121]
#  [ -3.41704937]
#  [-10.64341949]
#  [  2.81760763]]
# --The norm of the gradient vector |g(x_20)|: 15.516994963074376
# --The h vector h_20:
# [[-10.38651121]
#  [  3.41704937]
#  [ 10.64341949]
#  [ -2.81760763]]
# --The solution vector x_21:
# [[ 2.20737011]
#  [-0.22853337]
#  [ 0.24552472]
#  [ 1.5728251 ]]
#
# ****************************************************
# --At iteration: 21
# --The gradient vector g(x_21):
# [[ 10.0639877 ]
#  [ -3.04967074]
#  [-10.29220718]
#  [  3.05308883]]
# --The norm of the gradient vector |g(x_21)|: 15.027814879005815
# --The h vector h_21:
# [[-10.0639877 ]
#  [  3.04967074]
#  [ 10.29220718]
#  [ -3.05308883]]
# --The solution vector x_22:
# [[ 2.19730612]
#  [-0.2254837 ]
#  [ 0.25581693]
#  [ 1.56977201]]
#
# ****************************************************
# --At iteration: 22
# --The gradient vector g(x_22):
# [[ 9.76983171]
#  [-2.75264665]
#  [-9.9354936 ]
#  [ 3.2546573 ]]
# --The norm of the gradient vector |g(x_22)|: 14.57166780372637
# --The h vector h_22:
# [[-9.76983171]
#  [ 2.75264665]
#  [ 9.9354936 ]
#  [-3.2546573 ]]
# --The solution vector x_23:
# [[ 2.18753629]
#  [-0.22273106]
#  [ 0.26575242]
#  [ 1.56651735]]
#
# ****************************************************
# --At iteration: 23
# --The gradient vector g(x_23):
# [[ 9.50065005]
#  [-2.51173948]
#  [-9.57514104]
#  [ 3.42745072]]
# --The norm of the gradient vector |g(x_23)|: 14.142203895981485
# --The h vector h_23:
# [[-9.50065005]
#  [ 2.51173948]
#  [ 9.57514104]
#  [-3.42745072]]
# --The solution vector x_24:
# [[ 2.17803564]
#  [-0.22021932]
#  [ 0.27532756]
#  [ 1.5630899 ]]
#
# ****************************************************
# --At iteration: 24
# --The gradient vector g(x_24):
# [[ 9.25355714]
#  [-2.31551103]
#  [-9.21290225]
#  [ 3.5757512 ]]
# --The norm of the gradient vector |g(x_24)|: 13.735118332421582
# --The h vector h_24:
# [[-9.25355714]
#  [ 2.31551103]
#  [ 9.21290225]
#  [-3.5757512 ]]
# --The solution vector x_25:
# [[ 2.16878208]
#  [-0.2179038 ]
#  [ 0.28454047]
#  [ 1.55951415]]
#
# ****************************************************
# --At iteration: 25
# --The gradient vector g(x_25):
# [[ 9.02607874]
#  [-2.15477958]
#  [-8.85041648]
#  [ 3.70314617]]
# --The norm of the gradient vector |g(x_25)|: 13.347521718521518
# --The h vector h_25:
# [[-9.02607874]
#  [ 2.15477958]
#  [ 8.85041648]
#  [-3.70314617]]
# --The solution vector x_26:
# [[ 2.159756  ]
#  [-0.21574903]
#  [ 0.29339088]
#  [ 1.55581101]]
#
# ****************************************************
# --At iteration: 26
# --The gradient vector g(x_26):
# [[ 8.81607824]
#  [-2.02218309]
#  [-8.48920516]
#  [ 3.81265449]]
# --The norm of the gradient vector |g(x_26)|: 12.977495843488061
# --The h vector h_26:
# [[-8.81607824]
#  [ 2.02218309]
#  [ 8.48920516]
#  [-3.81265449]]
# --The solution vector x_27:
# [[ 2.15093992]
#  [-0.21372684]
#  [ 0.30188009]
#  [ 1.55199835]]
#
# ****************************************************
# --At iteration: 27
# --The gradient vector g(x_27):
# [[ 8.62169946]
#  [-1.91182734]
#  [-8.13066796]
#  [ 3.90682618]]
# --The norm of the gradient vector |g(x_27)|: 12.623780633086122
# --The h vector h_27:
# [[-8.62169946]
#  [ 1.91182734]
#  [ 8.13066796]
#  [-3.90682618]]
# --The solution vector x_28:
# [[ 2.14231822]
#  [-0.21181501]
#  [ 0.31001076]
#  [ 1.54809153]]
#
# ****************************************************
# --At iteration: 28
# --The gradient vector g(x_28):
# [[ 8.4413216 ]
#  [-1.81900235]
#  [-7.77608004]
#  [ 3.98782224]]
# --The norm of the gradient vector |g(x_28)|: 12.285553584773952
# --The h vector h_28:
# [[-8.4413216 ]
#  [ 1.81900235]
#  [ 7.77608004]
#  [-3.98782224]]
# --The solution vector x_29:
# [[ 2.1338769 ]
#  [-0.20999601]
#  [ 0.31778684]
#  [ 1.5441037 ]]
#
# ****************************************************
# --At iteration: 29
# --The gradient vector g(x_29):
# [[ 8.27352321]
#  [-1.73995351]
#  [-7.42659061]
#  [ 4.05747901]]
# --The norm of the gradient vector |g(x_29)|: 11.96227438964725
# --The h vector h_29:
# [[-8.27352321]
#  [ 1.73995351]
#  [ 7.42659061]
#  [-4.05747901]]
# --The solution vector x_30:
# [[ 2.12560338]
#  [-0.20825606]
#  [ 0.32521343]
#  [ 1.54004622]]
#
# ****************************************************
# --At iteration: 30
# --The gradient vector g(x_30):
# [[ 8.117053  ]
#  [-1.67169673]
#  [-7.083223  ]
#  [ 4.11736055]]
# --The norm of the gradient vector |g(x_30)|: 11.653575646369386
# --The h vector h_30:
# [[-8.117053  ]
#  [ 1.67169673]
#  [ 7.083223  ]
#  [-4.11736055]]
# --The solution vector x_31:
# [[ 2.11748632]
#  [-0.20658436]
#  [ 0.33229665]
#  [ 1.53592886]]
#
# ****************************************************
# --At iteration: 31
# --The gradient vector g(x_31):
# [[ 7.97080598]
#  [-1.61186892]
#  [-6.74687622]
#  [ 4.16880157]]
# --The norm of the gradient vector |g(x_31)|: 11.359186348479222
# --The h vector h_31:
# [[-7.97080598]
#  [ 1.61186892]
#  [ 6.74687622]
#  [-4.16880157]]
# --The solution vector x_32:
# [[ 2.10951552]
#  [-0.20497249]
#  [ 0.33904353]
#  [ 1.53176006]]
#
# ****************************************************
# --At iteration: 32
# --The gradient vector g(x_32):
# [[ 7.83380364]
#  [-1.55860701]
#  [-6.41832793]
#  [ 4.21294289]]
# --The norm of the gradient vector |g(x_32)|: 11.078878845515268
# --The h vector h_32:
# [[-7.83380364]
#  [ 1.55860701]
#  [ 6.41832793]
#  [-4.21294289]]
# --The solution vector x_33:
# [[ 2.10168172]
#  [-0.20341389]
#  [ 0.34546185]
#  [ 1.52754712]]
#
# ****************************************************
# --At iteration: 33
# --The gradient vector g(x_33):
# [[ 7.70517745]
#  [-1.51044994]
#  [-6.0982387 ]
#  [ 4.2507609 ]]
# --The norm of the gradient vector |g(x_33)|: 10.8124327543342
# --The h vector h_33:
# [[-7.70517745]
#  [ 1.51044994]
#  [ 6.0982387 ]
#  [-4.2507609 ]]
# --The solution vector x_34:
# [[ 2.09397654]
#  [-0.20190344]
#  [ 0.35156009]
#  [ 1.52329636]]
#
# ****************************************************
# --At iteration: 34
# --The gradient vector g(x_34):
# [[ 7.58415484]
#  [-1.4662592 ]
#  [-5.78715731]
#  [ 4.28309216]]
# --The norm of the gradient vector |g(x_34)|: 10.55961120719313
# --The h vector h_34:
# [[-7.58415484]
#  [ 1.4662592 ]
#  [ 5.78715731]
#  [-4.28309216]]
# --The solution vector x_35:
# [[ 2.08639238]
#  [-0.20043718]
#  [ 0.35734725]
#  [ 1.51901327]]
#
# ****************************************************
# --At iteration: 35
# --The gradient vector g(x_35):
# [[ 7.47004735]
#  [-1.4251544 ]
#  [-5.48552692]
#  [ 4.31065403]]
# --The norm of the gradient vector |g(x_35)|: 10.320146136644599
# --The h vector h_35:
# [[-7.47004735]
#  [ 1.4251544 ]
#  [ 5.48552692]
#  [-4.31065403]]
# --The solution vector x_36:
# [[ 2.07892234]
#  [-0.19901202]
#  [ 0.36283278]
#  [ 1.51470261]]
#
# ****************************************************
# --At iteration: 36
# --The gradient vector g(x_36):
# [[ 7.36224042]
#  [-1.38646103]
#  [-5.19369199]
#  [ 4.33406214]]
# --The norm of the gradient vector |g(x_36)|: 10.09373020240391
# --The h vector h_36:
# [[-7.36224042]
#  [ 1.38646103]
#  [ 5.19369199]
#  [-4.33406214]]
# --The solution vector x_37:
# [[ 2.0715601 ]
#  [-0.19762556]
#  [ 0.36802647]
#  [ 1.51036855]]
#
# ****************************************************
# --At iteration: 37
# --The gradient vector g(x_37):
# [[ 7.26018466]
#  [-1.34966808]
#  [-4.91190555]
#  [ 4.3538451 ]]
# --The norm of the gradient vector |g(x_37)|: 9.880013592443571
# --The h vector h_37:
# [[-7.26018466]
#  [ 1.34966808]
#  [ 4.91190555]
#  [-4.3538451 ]]
# --The solution vector x_38:
# [[ 2.06429991]
#  [-0.19627589]
#  [ 0.37293837]
#  [ 1.5060147 ]]
#
# ****************************************************
# --At iteration: 38
# --The gradient vector g(x_38):
# [[ 7.16338821]
#  [-1.31439375]
#  [-4.64033687]
#  [ 4.37045704]]
# --The norm of the gradient vector |g(x_38)|: 9.67860436921947
# --The h vector h_38:
# [[-7.16338821]
#  [ 1.31439375]
#  [ 4.64033687]
#  [-4.37045704]]
# --The solution vector x_39:
# [[ 2.05713652]
#  [-0.1949615 ]
#  [ 0.37757871]
#  [ 1.50164425]]
#
# ****************************************************
# --At iteration: 39
# --The gradient vector g(x_39):
# [[ 7.07141013]
#  [-1.28035764]
#  [-4.37907916]
#  [ 4.38428828]]
# --The norm of the gradient vector |g(x_39)|: 9.489071343374642
# --The h vector h_39:
# [[-7.07141013]
#  [ 1.28035764]
#  [ 4.37907916]
#  [-4.38428828]]
# --The solution vector x_40:
# [[ 2.05006511]
#  [-0.19368114]
#  [ 0.38195779]
#  [ 1.49725996]]
#
# ****************************************************
# --At iteration: 40
# --The gradient vector g(x_40):
# [[ 6.98385465]
#  [-1.24735839]
#  [-4.12815735]
#  [ 4.39567442]]
# --The norm of the gradient vector |g(x_40)|: 9.3109486831683
# --The h vector h_40:
# [[-6.98385465]
#  [ 1.24735839]
#  [ 4.12815735]
#  [-4.39567442]]
# --The solution vector x_41:
# [[ 2.04308126]
#  [-0.19243378]
#  [ 0.38608595]
#  [ 1.49286429]]
#
# ****************************************************
# --At iteration: 41
# --The gradient vector g(x_41):
# [[ 6.90036604]
#  [-1.21525553]
#  [-3.88753558]
#  [ 4.40490417]]
# --The norm of the gradient vector |g(x_41)|: 9.143741636408409
# --The h vector h_41:
# [[-6.90036604]
#  [ 1.21525553]
#  [ 3.88753558]
#  [-4.40490417]]
# --The solution vector x_42:
# [[ 2.03618089]
#  [-0.19121853]
#  [ 0.38997348]
#  [ 1.48845938]]
#
# ****************************************************
# --At iteration: 42
# --The gradient vector g(x_42):
# [[ 6.82062421]
#  [-1.18395505]
#  [-3.65712458]
#  [ 4.41222598]]
# --The norm of the gradient vector |g(x_42)|: 8.986932871669865
# --The h vector h_42:
# [[-6.82062421]
#  [ 1.18395505]
#  [ 3.65712458]
#  [-4.41222598]]
# --The solution vector x_43:
# [[ 2.02936027]
#  [-0.19003457]
#  [ 0.39363061]
#  [ 1.48404716]]
#
# ****************************************************
# --At iteration: 43
# --The gradient vector g(x_43):
# [[ 6.74434074]
#  [-1.15339776]
#  [-3.43678859]
#  [ 4.41785379]]
# --The norm of the gradient vector |g(x_43)|: 8.839989049451992
# --The h vector h_43:
# [[-6.74434074]
#  [ 1.15339776]
#  [ 3.43678859]
#  [-4.41785379]]
# --The solution vector x_44:
# [[ 2.02261593]
#  [-0.18888118]
#  [ 0.3970674 ]
#  [ 1.4796293 ]]
#
# ****************************************************
# --At iteration: 44
# --The gradient vector g(x_44):
# [[ 6.67125541]
#  [-1.12355011]
#  [-3.226352  ]
#  [ 4.42197197]]
# --The norm of the gradient vector |g(x_44)|: 8.702367319617235
# --The h vector h_44:
# [[-6.67125541]
#  [ 1.12355011]
#  [ 3.226352  ]
#  [-4.42197197]]
# --The solution vector x_45:
# [[ 2.01594467]
#  [-0.18775763]
#  [ 0.40029375]
#  [ 1.47520733]]
#
# ****************************************************
# --At iteration: 45
# --The gradient vector g(x_45):
# [[ 6.60113315]
#  [-1.09439685]
#  [-3.02560544]
#  [ 4.42473949]]
# --The norm of the gradient vector |g(x_45)|: 8.573521513875425
# --The h vector h_45:
# [[-6.60113315]
#  [ 1.09439685]
#  [ 3.02560544]
#  [-4.42473949]]
# --The solution vector x_46:
# [[ 2.00934354]
#  [-0.18666323]
#  [ 0.40331935]
#  [ 1.47078259]]
#
# ****************************************************
# --At iteration: 46
# --The gradient vector g(x_46):
# [[ 6.53376128]
#  [-1.06593538]
#  [-2.83431153]
#  [ 4.42629358]]
# --The norm of the gradient vector |g(x_46)|: 8.45290786413703
# --The h vector h_46:
# [[-6.53376128]
#  [ 1.06593538]
#  [ 2.83431153]
#  [-4.42629358]]
# --The solution vector x_47:
# [[ 2.00280978]
#  [-0.18559729]
#  [ 0.40615367]
#  [ 1.4663563 ]]
#
# ****************************************************
# --At iteration: 47
# --The gradient vector g(x_47):
# [[ 6.46894714]
#  [-1.03817126]
#  [-2.65221   ]
#  [ 4.42675286]]
# --The norm of the gradient vector |g(x_47)|: 8.339990130878569
# --The h vector h_47:
# [[-6.46894714]
#  [ 1.03817126]
#  [ 2.65221   ]
#  [-4.42675286]]
# --The solution vector x_48:
# [[ 1.99634083]
#  [-0.18455912]
#  [ 0.40880588]
#  [ 1.46192954]]
#
# ****************************************************
# --At iteration: 48
# --The gradient vector g(x_48):
# [[ 6.40651591]
#  [-1.01111488]
#  [-2.47902252]
#  [ 4.42621998]]
# --The norm of the gradient vector |g(x_48)|: 8.234244071118667
# --The h vector h_48:
# [[-6.40651591]
#  [ 1.01111488]
#  [ 2.47902252]
#  [-4.42621998]]
# --The solution vector x_49:
# [[ 1.98993431]
#  [-0.18354801]
#  [ 0.4112849 ]
#  [ 1.45750332]]
#
# ****************************************************
# --At iteration: 49
# --The gradient vector g(x_49):
# [[ 6.34630874]
#  [-0.98477884]
#  [-2.31445687]
#  [ 4.424784  ]]
# --The norm of the gradient vector |g(x_49)|: 8.135161213693731
# --The h vector h_49:
# [[-6.34630874]
#  [ 0.98477884]
#  [ 2.31445687]
#  [-4.424784  ]]
# --The solution vector x_50:
# [[ 1.983588  ]
#  [-0.18256323]
#  [ 0.41359936]
#  [ 1.45307854]]
#
# ****************************************************
# --At iteration: 50
# --The gradient vector g(x_50):
# [[ 6.28818102]
#  [-0.95917608]
#  [-2.15821078]
#  [ 4.42252226]]
# --The norm of the gradient vector |g(x_50)|: 8.042251940617
# --The h vector h_50:
# [[-6.28818102]
#  [ 0.95917608]
#  [ 2.15821078]
#  [-4.42252226]]
# --The solution vector x_51:
# [[ 1.97729982]
#  [-0.18160405]
#  [ 0.41575757]
#  [ 1.44865602]]
#
# ****************************************************
# --At iteration: 51
# --The gradient vector g(x_51):
# [[ 6.23200092]
#  [-0.93431856]
#  [-2.00997531]
#  [ 4.41950219]]
# --The norm of the gradient vector |g(x_51)|: 7.955047897794281
# --The h vector h_51:
# [[-6.23200092]
#  [ 0.93431856]
#  [ 2.00997531]
#  [-4.41950219]]
# --The solution vector x_52:
# [[ 1.97106782]
#  [-0.18066973]
#  [ 0.41776754]
#  [ 1.44423651]]
#
# ****************************************************
# --At iteration: 52
# --The gradient vector g(x_52):
# [[ 6.17764802]
#  [-0.91021623]
#  [-1.8694378 ]
#  [ 4.41578269]]
# --The norm of the gradient vector |g(x_52)|: 7.873103776735805
# --The h vector h_52:
# [[-6.17764802]
#  [ 0.91021623]
#  [ 1.8694378 ]
#  [-4.41578269]]
# --The solution vector x_53:
# [[ 1.96489018]
#  [-0.17975952]
#  [ 0.41963698]
#  [ 1.43982073]]
#
# ****************************************************
# --At iteration: 53
# --The gradient vector g(x_53):
# [[ 6.12501213]
#  [-0.88687655]
#  [-1.7362844 ]
#  [ 4.41141541]]
# --The norm of the gradient vector |g(x_53)|: 7.795998521741553
# --The h vector h_53:
# [[-6.12501213]
#  [ 0.88687655]
#  [ 1.7362844 ]
#  [-4.41141541]]
# --The solution vector x_54:
# [[ 1.95876516]
#  [-0.17887264]
#  [ 0.42137326]
#  [ 1.43540932]]
#
# ****************************************************
# --At iteration: 54
# --The gradient vector g(x_54):
# [[ 6.07399224]
#  [-0.86430401]
#  [-1.61020235]
#  [ 4.4064458 ]]
# --The norm of the gradient vector |g(x_54)|: 7.723336025037307
# --The h vector h_54:
# [[-6.07399224]
#  [ 0.86430401]
#  [ 1.61020235]
#  [-4.4064458 ]]
# --The solution vector x_55:
# [[ 1.95269117]
#  [-0.17800834]
#  [ 0.42298347]
#  [ 1.43100287]]
#
# ****************************************************
# --At iteration: 55
# --The gradient vector g(x_55):
# [[ 6.0244956 ]
#  [-0.84250007]
#  [-1.49088183]
#  [ 4.40091405]]
# --The norm of the gradient vector |g(x_55)|: 7.654745376251038
# --The h vector h_55:
# [[-6.0244956 ]
#  [ 0.84250007]
#  [ 1.49088183]
#  [-4.40091405]]
# --The solution vector x_56:
# [[ 1.94666668]
#  [-0.17716584]
#  [ 0.42447435]
#  [ 1.42660196]]
#
# ****************************************************
# --At iteration: 56
# --The gradient vector g(x_56):
# [[ 5.97643685]
#  [-0.8214631 ]
#  [-1.3780176 ]
#  [ 4.39485586]]
# --The norm of the gradient vector |g(x_56)|: 7.589880733212565
# --The h vector h_56:
# [[-5.97643685]
#  [ 0.8214631 ]
#  [ 1.3780176 ]
#  [-4.39485586]]
# --The solution vector x_57:
# [[ 1.94069024]
#  [-0.17634437]
#  [ 0.42585237]
#  [ 1.4222071 ]]
#
# ****************************************************
# --At iteration: 57
# --The gradient vector g(x_57):
# [[ 5.92973727]
#  [-0.80118852]
#  [-1.27131026]
#  [ 4.38830309]]
# --The norm of the gradient vector |g(x_57)|: 7.528420879078982
# --The h vector h_57:
# [[-5.92973727]
#  [ 0.80118852]
#  [ 1.27131026]
#  [-4.38830309]]
# --The solution vector x_58:
# [[ 1.9347605 ]
#  [-0.17554319]
#  [ 0.42712368]
#  [ 1.4178188 ]]
#
# ****************************************************
# --At iteration: 58
# --The gradient vector g(x_58):
# [[ 5.88432417]
#  [-0.78166891]
#  [-1.17046742]
#  [ 4.38128436]]
# --The norm of the gradient vector |g(x_58)|: 7.4700685269237415
# --The h vector h_58:
# [[-5.88432417]
#  [ 0.78166891]
#  [ 1.17046742]
#  [-4.38128436]]
# --The solution vector x_59:
# [[ 1.92887618]
#  [-0.17476152]
#  [ 0.42829414]
#  [ 1.41343751]]
#
# ****************************************************
# --At iteration: 59
# --The gradient vector g(x_59):
# [[ 5.84013025]
#  [-0.7628943 ]
#  [-1.07520452]
#  [ 4.37382548]]
# --The norm of the gradient vector |g(x_59)|: 7.414549427789002
# --The h vector h_59:
# [[-5.84013025]
#  [ 0.7628943 ]
#  [ 1.07520452]
#  [-4.37382548]]
# --The solution vector x_60:
# [[ 1.92303605]
#  [-0.17399862]
#  [ 0.42936935]
#  [ 1.40906369]]
#
# ****************************************************
# --At iteration: 60
# --The gradient vector g(x_60):
# [[ 5.79709312]
#  [-0.74485239]
#  [-0.98524555]
#  [ 4.36594994]]
# --The norm of the gradient vector |g(x_60)|: 7.361611332306607
# --The h vector h_60:
# [[-5.79709312]
#  [ 0.74485239]
#  [ 0.98524555]
#  [-4.36594994]]
# --The solution vector x_61:
# [[ 1.91723895]
#  [-0.17325377]
#  [ 0.43035459]
#  [ 1.40469774]]
#
# ****************************************************
# --At iteration: 61
# --The gradient vector g(x_61):
# [[ 5.75515479]
#  [-0.7275288 ]
#  [-0.90032353]
#  [ 4.35767917]]
# --The norm of the gradient vector |g(x_61)|: 7.311022849764544
# --The h vector h_61:
# [[-5.75515479]
#  [ 0.7275288 ]
#  [ 0.90032353]
#  [-4.35767917]]
# --The solution vector x_62:
# [[ 1.9114838 ]
#  [-0.17252624]
#  [ 0.43125492]
#  [ 1.40034006]]
#
# ****************************************************
# --At iteration: 62
# --The gradient vector g(x_62):
# [[ 5.7142613 ]
#  [-0.71090741]
#  [-0.82018095]
#  [ 4.34903291]]
# --The norm of the gradient vector |g(x_62)|: 7.262572242260232
# --The h vector h_62:
# [[-5.7142613 ]
#  [ 0.71090741]
#  [ 0.82018095]
#  [-4.34903291]]
# --The solution vector x_63:
# [[ 1.90576954]
#  [-0.17181533]
#  [ 0.4320751 ]
#  [ 1.39599103]]
#
# ****************************************************
# --At iteration: 63
# --The gradient vector g(x_63):
# [[ 5.6743623 ]
#  [-0.69497058]
#  [-0.74456997]
#  [ 4.3400294 ]]
# --The norm of the gradient vector |g(x_63)|: 7.216066185581776
# --The h vector h_63:
# [[-5.6743623 ]
#  [ 0.69497058]
#  [ 0.74456997]
#  [-4.3400294 ]]
# --The solution vector x_64:
# [[ 1.90009518]
#  [-0.17112036]
#  [ 0.43281967]
#  [ 1.391651  ]]
#
# ****************************************************
# --At iteration: 64
# --The gradient vector g(x_64):
# [[ 5.63541077]
#  [-0.67969942]
#  [-0.67325256]
#  [ 4.33068561]]
# --The norm of the gradient vector |g(x_64)|: 7.17132852286018
# --The h vector h_64:
# [[-5.63541077]
#  [ 0.67969942]
#  [ 0.67325256]
#  [-4.33068561]]
# --The solution vector x_65:
# [[ 1.89445976]
#  [-0.17044066]
#  [ 0.43349292]
#  [ 1.38732031]]
#
# ****************************************************
# --At iteration: 65
# --The gradient vector g(x_65):
# [[ 5.59736272]
#  [-0.66507404]
#  [-0.60600059]
#  [ 4.32101746]]
# --The norm of the gradient vector |g(x_65)|: 7.1281990319442645
# --The h vector h_65:
# [[-5.59736272]
#  [ 0.66507404]
#  [ 0.60600059]
#  [-4.32101746]]
# --The solution vector x_66:
# [[ 1.8888624 ]
#  [-0.16977559]
#  [ 0.43409892]
#  [ 1.38299929]]
#
# ****************************************************
# --At iteration: 66
# --The gradient vector g(x_66):
# [[ 5.56017687]
#  [-0.6510738 ]
#  [-0.54259579]
#  [ 4.31103987]]
# --The norm of the gradient vector |g(x_66)|: 7.086532222920392
# --The h vector h_66:
# [[-5.56017687]
#  [ 0.6510738 ]
#  [ 0.54259579]
#  [-4.31103987]]
# --The solution vector x_67:
# [[ 1.88330222]
#  [-0.16912452]
#  [ 0.43464152]
#  [ 1.37868825]]
#
# ****************************************************
# --At iteration: 67
# --The gradient vector g(x_67):
# [[ 5.52381452]
#  [-0.63767749]
#  [-0.48282961]
#  [ 4.300767  ]]
# --The norm of the gradient vector |g(x_67)|: 7.046196178246966
# --The h vector h_67:
# [[-5.52381452]
#  [ 0.63767749]
#  [ 0.48282961]
#  [-4.300767  ]]
# --The solution vector x_68:
# [[ 1.87777841]
#  [-0.16848684]
#  [ 0.43512435]
#  [ 1.37438749]]
#
# ****************************************************
# --At iteration: 68
# --The gradient vector g(x_68):
# [[ 5.48823922]
#  [-0.62486354]
#  [-0.42650313]
#  [ 4.29021225]]
# --The norm of the gradient vector |g(x_68)|: 7.007071444587632
# --The h vector h_68:
# [[-5.48823922]
#  [ 0.62486354]
#  [ 0.42650313]
#  [-4.29021225]]
# --The solution vector x_69:
# [[ 1.87229017]
#  [-0.16786197]
#  [ 0.43555085]
#  [ 1.37009727]]
#
# ****************************************************
# --At iteration: 69
# --The gradient vector g(x_69):
# [[ 5.45341669]
#  [-0.61261018]
#  [-0.37342685]
#  [ 4.27938842]]
# --The norm of the gradient vector |g(x_69)|: 6.969049982575479
# --The h vector h_69:
# [[-5.45341669]
#  [ 0.61261018]
#  [ 0.37342685]
#  [-4.27938842]]
# --The solution vector x_70:
# [[ 1.86683675]
#  [-0.16724936]
#  [ 0.43592428]
#  [ 1.36581789]]
#
# ****************************************************
# --At iteration: 70
# --The gradient vector g(x_70):
# [[ 5.41931459]
#  [-0.6008956 ]
#  [-0.32342044]
#  [ 4.26830773]]
# --The norm of the gradient vector |g(x_70)|: 6.932034178380199
# --The h vector h_70:
# [[-5.41931459]
#  [ 0.6008956 ]
#  [ 0.32342044]
#  [-4.26830773]]
# --The solution vector x_71:
# [[ 1.86141744]
#  [-0.16664847]
#  [ 0.4362477 ]
#  [ 1.36154958]]
#
# ****************************************************
# --At iteration: 71
# --The gradient vector g(x_71):
# [[ 5.38590239]
#  [-0.5896981 ]
#  [-0.27631251]
#  [ 4.25698194]]
# --The norm of the gradient vector |g(x_71)|: 6.8959359190306175
# --The h vector h_71:
# [[-5.38590239]
#  [ 0.5896981 ]
#  [ 0.27631251]
#  [-4.25698194]]
# --The solution vector x_72:
# [[ 1.85603154]
#  [-0.16605877]
#  [ 0.43652401]
#  [ 1.3572926 ]]
#
# ****************************************************
# --At iteration: 72
# --The gradient vector g(x_72):
# [[ 5.35315122]
#  [-0.57899616]
#  [-0.23194031]
#  [ 4.24542232]]
# --The norm of the gradient vector |g(x_72)|: 6.860675731913736
# --The h vector h_72:
# [[-5.35315122]
#  [ 0.57899616]
#  [ 0.23194031]
#  [-4.24542232]]
# --The solution vector x_73:
# [[ 1.85067839]
#  [-0.16547977]
#  [ 0.43675595]
#  [ 1.35304717]]
#
# ****************************************************
# --At iteration: 73
# --The gradient vector g(x_73):
# [[ 5.32103378]
#  [-0.56876857]
#  [-0.19014943]
#  [ 4.23363976]]
# --The norm of the gradient vector |g(x_73)|: 6.8261819876759215
# --The h vector h_73:
# [[-5.32103378]
#  [ 0.56876857]
#  [ 0.19014943]
#  [-4.23363976]]
# --The solution vector x_74:
# [[ 1.84535735]
#  [-0.16491101]
#  [ 0.4369461 ]
#  [ 1.34881353]]
#
# ****************************************************
# --At iteration: 74
# --The gradient vector g(x_74):
# [[ 5.28952418]
#  [-0.55899453]
#  [-0.15079355]
#  [ 4.22164476]]
# --The norm of the gradient vector |g(x_74)|: 6.792390164842595
# --The h vector h_74:
# [[-5.28952418]
#  [ 0.55899453]
#  [ 0.15079355]
#  [-4.22164476]]
# --The solution vector x_75:
# [[ 1.84006783]
#  [-0.16435201]
#  [ 0.43709689]
#  [ 1.34459189]]
#
# ****************************************************
# --At iteration: 75
# --The gradient vector g(x_75):
# [[ 5.25859791]
#  [-0.54965368]
#  [-0.11373403]
#  [ 4.2094475 ]]
# --The norm of the gradient vector |g(x_75)|: 6.759242173803631
# --The h vector h_75:
# [[-5.25859791]
#  [ 0.54965368]
#  [ 0.11373403]
#  [-4.2094475 ]]
# --The solution vector x_76:
# [[ 1.83480923]
#  [-0.16380236]
#  [ 0.43721063]
#  [ 1.34038244]]
#
# ****************************************************
# --At iteration: 76
# --The gradient vector g(x_76):
# [[ 5.22823166]
#  [-0.54072617]
#  [-0.07883968]
#  [ 4.1970578 ]]
# --The norm of the gradient vector |g(x_76)|: 6.726685737341181
# --The h vector h_76:
# [[-5.22823166]
#  [ 0.54072617]
#  [ 0.07883968]
#  [-4.1970578 ]]
# --The solution vector x_77:
# [[ 1.829581  ]
#  [-0.16326163]
#  [ 0.43728947]
#  [ 1.33618538]]
#
# ****************************************************
# --At iteration: 77
# --The gradient vector g(x_77):
# [[ 5.19840334]
#  [-0.53219272]
#  [-0.04598639]
#  [ 4.18448521]]
# --The norm of the gradient vector |g(x_77)|: 6.694673824568235
# --The h vector h_77:
# [[-5.19840334]
#  [ 0.53219272]
#  [ 0.04598639]
#  [-4.18448521]]
# --The solution vector x_78:
# [[ 1.8243826 ]
#  [-0.16272944]
#  [ 0.43733545]
#  [ 1.3320009 ]]
#
# ****************************************************
# --At iteration: 78
# --The gradient vector g(x_78):
# [[ 5.16909192]
#  [-0.52403466]
#  [-0.01505685]
#  [ 4.17173896]]
# --The norm of the gradient vector |g(x_78)|: 6.663164134968041
# --The h vector h_78:
# [[-5.16909192]
#  [ 0.52403466]
#  [ 0.01505685]
#  [-4.17173896]]
# --The solution vector x_79:
# [[ 1.8192135 ]
#  [-0.1622054 ]
#  [ 0.43735051]
#  [ 1.32782916]]
#
# ****************************************************
# --At iteration: 79
# --The gradient vector g(x_79):
# [[ 5.14027741]
#  [-0.51623391]
#  [ 0.0140598 ]
#  [ 4.15882803]]
# --The norm of the gradient vector |g(x_79)|: 6.632118629149057
# --The h vector h_79:
# [[-5.14027741]
#  [ 0.51623391]
#  [-0.0140598 ]
#  [-4.15882803]]
# --The solution vector x_80:
# [[ 1.81407323]
#  [-0.16168917]
#  [ 0.43733645]
#  [ 1.32367033]]
#
# ****************************************************
# --At iteration: 80
# --The gradient vector g(x_80):
# [[ 5.11194077]
#  [-0.50877306]
#  [ 0.04146825]
#  [ 4.14576111]]
# --The norm of the gradient vector |g(x_80)|: 6.601503102934472
# --The h vector h_80:
# [[-5.11194077]
#  [ 0.50877306]
#  [-0.04146825]
#  [-4.14576111]]
# --The solution vector x_81:
# [[ 1.80896129]
#  [-0.1611804 ]
#  [ 0.43729498]
#  [ 1.31952457]]
#
# ****************************************************
# --At iteration: 81
# --The gradient vector g(x_81):
# [[ 5.08406388]
#  [-0.50163534]
#  [ 0.06726733]
#  [ 4.13254665]]
# --The norm of the gradient vector |g(x_81)|: 6.571286801470165
# --The h vector h_81:
# [[-5.08406388]
#  [ 0.50163534]
#  [-0.06726733]
#  [-4.13254665]]
# --The solution vector x_82:
# [[ 1.80387722]
#  [-0.16067876]
#  [ 0.43722771]
#  [ 1.31539202]]
#
# ****************************************************
# --At iteration: 82
# --The gradient vector g(x_82):
# [[ 5.05662948]
#  [-0.49480462]
#  [ 0.09155027]
#  [ 4.11919283]]
# --The norm of the gradient vector |g(x_82)|: 6.5414420701442415
# --The h vector h_82:
# [[-5.05662948]
#  [ 0.49480462]
#  [-0.09155027]
#  [-4.11919283]]
# --The solution vector x_83:
# [[ 1.79882059]
#  [-0.16018396]
#  [ 0.43713616]
#  [ 1.31127283]]
#
# ****************************************************
# --At iteration: 83
# --The gradient vector g(x_83):
# [[ 5.02962111]
#  [-0.48826547]
#  [ 0.11440506]
#  [ 4.10570761]]
# --The norm of the gradient vector |g(x_83)|: 6.511944039252206
# --The h vector h_83:
# [[-5.02962111]
#  [ 0.48826547]
#  [-0.11440506]
#  [-4.10570761]]
# --The solution vector x_84:
# [[ 1.79379097]
#  [-0.15969569]
#  [ 0.43702176]
#  [ 1.30716712]]
#
# ****************************************************
# --At iteration: 84
# --The gradient vector g(x_84):
# [[ 5.00302306]
#  [-0.48200307]
#  [ 0.13591463]
#  [ 4.0920987 ]]
# --The norm of the gradient vector |g(x_84)|: 6.482770339503813
# --The h vector h_84:
# [[-5.00302306]
#  [ 0.48200307]
#  [-0.13591463]
#  [-4.0920987 ]]
# --The solution vector x_85:
# [[ 1.78878795]
#  [-0.15921369]
#  [ 0.43688584]
#  [ 1.30307503]]
#
# ****************************************************
# --At iteration: 85
# --The gradient vector g(x_85):
# [[ 4.97682037]
#  [-0.47600327]
#  [ 0.15615717]
#  [ 4.07837356]]
# --The norm of the gradient vector |g(x_85)|: 6.453900845642388
# --The h vector h_85:
# [[-4.97682037]
#  [ 0.47600327]
#  [-0.15615717]
#  [-4.07837356]]
# --The solution vector x_86:
# [[ 1.78381113]
#  [-0.15873769]
#  [ 0.43672969]
#  [ 1.29899665]]
#
# ****************************************************
# --At iteration: 86
# --The gradient vector g(x_86):
# [[ 4.95099875]
#  [-0.47025255]
#  [ 0.17520639]
#  [ 4.06453945]]
# --The norm of the gradient vector |g(x_86)|: 6.425317445628499
# --The h vector h_86:
# [[-4.95099875]
#  [ 0.47025255]
#  [-0.17520639]
#  [-4.06453945]]
# --The solution vector x_87:
# [[ 1.77886013]
#  [-0.15826743]
#  [ 0.43655448]
#  [ 1.29493211]]
#
# ****************************************************
# --At iteration: 87
# --The gradient vector g(x_87):
# [[ 4.92554454]
#  [-0.46473801]
#  [ 0.19313171]
#  [ 4.05060338]]
# --The norm of the gradient vector |g(x_87)|: 6.3970038330222065
# --The h vector h_87:
# [[-4.92554454]
#  [ 0.46473801]
#  [-0.19313171]
#  [-4.05060338]]
# --The solution vector x_88:
# [[ 1.77393458]
#  [-0.15780269]
#  [ 0.43636135]
#  [ 1.29088151]]
#
# ****************************************************
# --At iteration: 88
# --The gradient vector g(x_88):
# [[ 4.90044473]
#  [-0.45944736]
#  [ 0.20999854]
#  [ 4.03657214]]
# --The norm of the gradient vector |g(x_88)|: 6.368945320377977
# --The h vector h_88:
# [[-4.90044473]
#  [ 0.45944736]
#  [-0.20999854]
#  [-4.03657214]]
# --The solution vector x_89:
# [[ 1.76903414]
#  [-0.15734325]
#  [ 0.43615135]
#  [ 1.28684494]]
#
# ****************************************************
# --At iteration: 89
# --The gradient vector g(x_89):
# [[ 4.87568687]
#  [-0.45436888]
#  [ 0.22586849]
#  [ 4.02245233]]
# --The norm of the gradient vector |g(x_89)|: 6.341128671640923
# --The h vector h_89:
# [[-4.87568687]
#  [ 0.45436888]
#  [-0.22586849]
#  [-4.02245233]]
# --The solution vector x_90:
# [[ 1.76415845]
#  [-0.15688888]
#  [ 0.43592548]
#  [ 1.28282248]]
#
# ****************************************************
# --At iteration: 90
# --The gradient vector g(x_90):
# [[ 4.85125907]
#  [-0.44949146]
#  [ 0.24079956]
#  [ 4.00825029]]
# --The norm of the gradient vector |g(x_90)|: 6.313541951700403
# --The h vector h_90:
# [[-4.85125907]
#  [ 0.44949146]
#  [-0.24079956]
#  [-4.00825029]]
# --The solution vector x_91:
# [[ 1.75930719]
#  [-0.15643939]
#  [ 0.43568468]
#  [ 1.27881423]]
#
# ****************************************************
# --At iteration: 91
# --The gradient vector g(x_91):
# [[ 4.82714998]
#  [-0.44480451]
#  [ 0.25484639]
#  [ 3.99397219]]
# --The norm of the gradient vector |g(x_91)|: 6.286174391415725
# --The h vector h_91:
# [[-4.82714998]
#  [ 0.44480451]
#  [-0.25484639]
#  [-3.99397219]]
# --The solution vector x_92:
# [[ 1.75448004]
#  [-0.15599458]
#  [ 0.43542984]
#  [ 1.27482026]]
#
# ****************************************************
# --At iteration: 92
# --The gradient vector g(x_92):
# [[ 4.80334873]
#  [-0.44029797]
#  [ 0.26806038]
#  [ 3.97962397]]
# --The norm of the gradient vector |g(x_92)|: 6.259016266578188
# --The h vector h_92:
# [[-4.80334873]
#  [ 0.44029797]
#  [-0.26806038]
#  [-3.97962397]]
# --The solution vector x_93:
# [[ 1.74967669]
#  [-0.15555428]
#  [ 0.43516178]
#  [ 1.27084064]]
#
# ****************************************************
# --At iteration: 93
# --The gradient vector g(x_93):
# [[ 4.77984496]
#  [-0.43596232]
#  [ 0.28048995]
#  [ 3.96521137]]
# --The norm of the gradient vector |g(x_93)|: 6.232058789413144
# --The h vector h_93:
# [[-4.77984496]
#  [ 0.43596232]
#  [-0.28048995]
#  [-3.96521137]]
# --The solution vector x_94:
# [[ 1.74489685]
#  [-0.15511832]
#  [ 0.43488129]
#  [ 1.26687543]]
#
# ****************************************************
# --At iteration: 94
# --The gradient vector g(x_94):
# [[ 4.75662873]
#  [-0.4317885 ]
#  [ 0.29218065]
#  [ 3.95073993]]
# --The norm of the gradient vector |g(x_94)|: 6.205294011355524
# --The h vector h_94:
# [[-4.75662873]
#  [ 0.4317885 ]
#  [-0.29218065]
#  [-3.95073993]]
# --The solution vector x_95:
# [[ 1.74014022]
#  [-0.15468653]
#  [ 0.4345891 ]
#  [ 1.26292469]]
#
# ****************************************************
# --At iteration: 95
# --The gradient vector g(x_95):
# [[ 4.73369058]
#  [-0.42776794]
#  [ 0.30317537]
#  [ 3.93621501]]
# --The norm of the gradient vector |g(x_95)|: 6.17871473595194
# --The h vector h_95:
# [[-4.73369058]
#  [ 0.42776794]
#  [-0.30317537]
#  [-3.93621501]]
# --The solution vector x_96:
# [[ 1.73540653]
#  [-0.15425877]
#  [ 0.43428593]
#  [ 1.25898847]]
#
# ****************************************************
# --At iteration: 96
# --The gradient vector g(x_96):
# [[ 4.71102141]
#  [-0.42389251]
#  [ 0.31351446]
#  [ 3.92164175]]
# --The norm of the gradient vector |g(x_96)|: 6.15231444085282
# --The h vector h_96:
# [[-4.71102141]
#  [ 0.42389251]
#  [-0.31351446]
#  [-3.92164175]]
# --The solution vector x_97:
# [[ 1.73069551]
#  [-0.15383487]
#  [ 0.43397241]
#  [ 1.25506683]]
#
# ****************************************************
# --At iteration: 97
# --The gradient vector g(x_97):
# [[ 4.68861257]
#  [-0.42015452]
#  [ 0.3232359 ]
#  [ 3.90702513]]
# --The norm of the gradient vector |g(x_97)|: 6.1260872079589745
# --The h vector h_97:
# [[-4.68861257]
#  [ 0.42015452]
#  [-0.3232359 ]
#  [-3.90702513]]
# --The solution vector x_98:
# [[ 1.7260069 ]
#  [-0.15341472]
#  [ 0.43364918]
#  [ 1.2511598 ]]
#
# ****************************************************
# --At iteration: 98
# --The gradient vector g(x_98):
# [[ 4.66645575]
#  [-0.41654669]
#  [ 0.33237543]
#  [ 3.89236993]]
# --The norm of the gradient vector |g(x_98)|: 6.100027660879362
# --The h vector h_98:
# [[-4.66645575]
#  [ 0.41654669]
#  [-0.33237543]
#  [-3.89236993]]
# --The solution vector x_99:
# [[ 1.72134044]
#  [-0.15299817]
#  [ 0.4333168 ]
#  [ 1.24726743]]
#
# ****************************************************
# --At iteration: 99
# --The gradient vector g(x_99):
# [[ 4.64454301]
#  [-0.41306211]
#  [ 0.34096668]
#  [ 3.87768074]]
# --The norm of the gradient vector |g(x_99)|: 6.074130908940898
# --The h vector h_99:
# [[-4.64454301]
#  [ 0.41306211]
#  [-0.34096668]
#  [-3.87768074]]
# --The solution vector x_100:
# [[ 1.7166959 ]
#  [-0.15258511]
#  [ 0.43297584]
#  [ 1.24338975]]
#
# ****************************************************
# --At iteration: 100
# --The gradient vector g(x_100):
# [[ 4.62286677]
#  [-0.40969429]
#  [ 0.34904129]
#  [ 3.862962  ]]
# --The norm of the gradient vector |g(x_100)|: 6.048392497067603
# --The h vector h_100:
# [[-4.62286677]
#  [ 0.40969429]
#  [-0.34904129]
#  [-3.862962  ]]
# --The solution vector x_101:
# [[ 1.71207303]
#  [-0.15217542]
#  [ 0.4326268 ]
#  [ 1.23952679]]
#
# ****************************************************
# --At iteration: 101
# --The gradient vector g(x_101):
# [[ 4.60141976]
#  [-0.40643704]
#  [ 0.35662904]
#  [ 3.84821795]]
# --The norm of the gradient vector |g(x_101)|: 6.022808360915661
# --The h vector h_101:
# [[-4.60141976]
#  [ 0.40643704]
#  [-0.35662904]
#  [-3.84821795]]
# --The solution vector x_102:
# [[ 1.70747161]
#  [-0.15176898]
#  [ 0.43227017]
#  [ 1.23567857]]
#
# ****************************************************
# --At iteration: 102
# --The gradient vector g(x_102):
# [[ 4.58019502]
#  [-0.40328454]
#  [ 0.36375796]
#  [ 3.8334527 ]]
# --The norm of the gradient vector |g(x_102)|: 5.9973747867137135
# --The h vector h_102:
# [[-4.58019502]
#  [ 0.40328454]
#  [-0.36375796]
#  [-3.8334527 ]]
# --The solution vector x_103:
# [[ 1.70289142]
#  [-0.15136569]
#  [ 0.43190641]
#  [ 1.23184512]]
#
# ****************************************************
# --At iteration: 103
# --The gradient vector g(x_103):
# [[ 4.55918591]
#  [-0.40023128]
#  [ 0.37045441]
#  [ 3.81867017]]
# --The norm of the gradient vector |g(x_103)|: 5.972088375314335
# --The h vector h_103:
# [[-4.55918591]
#  [ 0.40023128]
#  [-0.37045441]
#  [-3.81867017]]
# --The solution vector x_104:
# [[ 1.69833223]
#  [-0.15096546]
#  [ 0.43153595]
#  [ 1.22802645]]
#
# ****************************************************
# --At iteration: 104
# --The gradient vector g(x_104):
# [[ 4.53838606]
#  [-0.39727207]
#  [ 0.37674321]
#  [ 3.80387412]]
# --The norm of the gradient vector |g(x_104)|: 5.946946010013782
# --The h vector h_104:
# [[-4.53838606]
#  [ 0.39727207]
#  [-0.37674321]
#  [-3.80387412]]
# --The solution vector x_105:
# [[ 1.69379384]
#  [-0.15056819]
#  [ 0.43115921]
#  [ 1.22422258]]
#
# ****************************************************
# --At iteration: 105
# --The gradient vector g(x_105):
# [[ 4.51778937]
#  [-0.39440197]
#  [ 0.38264772]
#  [ 3.78906816]]
# --The norm of the gradient vector |g(x_105)|: 5.921944827743161
# --The h vector h_105:
# [[-4.51778937]
#  [ 0.39440197]
#  [-0.38264772]
#  [-3.78906816]]
# --The solution vector x_106:
# [[ 1.68927605]
#  [-0.15017379]
#  [ 0.43077656]
#  [ 1.22043351]]
#
# ****************************************************
# --At iteration: 106
# --The gradient vector g(x_106):
# [[ 4.49739003]
#  [-0.39161636]
#  [ 0.3881899 ]
#  [ 3.77425576]]
# --The norm of the gradient vector |g(x_106)|: 5.897082193275534
# --The h vector h_106:
# [[-4.49739003]
#  [ 0.39161636]
#  [-0.3881899 ]
#  [-3.77425576]]
# --The solution vector x_107:
# [[ 1.68477866]
#  [-0.14978217]
#  [ 0.43038837]
#  [ 1.21665925]]
#
# ****************************************************
# --At iteration: 107
# --The gradient vector g(x_107):
# [[ 4.47718243]
#  [-0.38891083]
#  [ 0.39339045]
#  [ 3.75944025]]
# --The norm of the gradient vector |g(x_107)|: 5.872355676130793
# --The h vector h_107:
# [[-4.47718243]
#  [ 0.38891083]
#  [-0.39339045]
#  [-3.75944025]]
# --The solution vector x_108:
# [[ 1.68030148]
#  [-0.14939326]
#  [ 0.42999498]
#  [ 1.21289981]]
#
# ****************************************************
# --At iteration: 108
# --The gradient vector g(x_108):
# [[ 4.45716125]
#  [-0.38628126]
#  [ 0.39826884]
#  [ 3.74462478]]
# --The norm of the gradient vector |g(x_108)|: 5.847763029893511
# --The h vector h_108:
# [[-4.45716125]
#  [ 0.38628126]
#  [-0.39826884]
#  [-3.74462478]]
# --The solution vector x_109:
# [[ 1.67584432]
#  [-0.14900698]
#  [ 0.42959671]
#  [ 1.20915519]]
#
# ****************************************************
# --At iteration: 109
# --The gradient vector g(x_109):
# [[ 4.43732136]
#  [-0.38372373]
#  [ 0.40284339]
#  [ 3.72981242]]
# --The norm of the gradient vector |g(x_109)|: 5.823302173689036
# --The h vector h_109:
# [[-4.43732136]
#  [ 0.38372373]
#  [-0.40284339]
#  [-3.72981242]]
# --The solution vector x_110:
# [[ 1.671407  ]
#  [-0.14862326]
#  [ 0.42919387]
#  [ 1.20542538]]
#
# ****************************************************
# --At iteration: 110
# --The gradient vector g(x_110):
# [[ 4.41765786]
#  [-0.38123454]
#  [ 0.40713135]
#  [ 3.71500606]]
# --The norm of the gradient vector |g(x_110)|: 5.798971175589926
# --The h vector h_110:
# [[-4.41765786]
#  [ 0.38123454]
#  [-0.40713135]
#  [-3.71500606]]
# --The solution vector x_111:
# [[ 1.66698934]
#  [-0.14824202]
#  [ 0.42878674]
#  [ 1.20171037]]
#
# ****************************************************
# --At iteration: 111
# --The gradient vector g(x_111):
# [[ 4.39816607]
#  [-0.37881023]
#  [ 0.41114896]
#  [ 3.70020848]]
# --The norm of the gradient vector |g(x_111)|: 5.774768237748987
# --The h vector h_111:
# [[-4.39816607]
#  [ 0.37881023]
#  [-0.41114896]
#  [-3.70020848]]
# --The solution vector x_112:
# [[ 1.66259118]
#  [-0.14786321]
#  [ 0.42837559]
#  [ 1.19801016]]
#
# ****************************************************
# --At iteration: 112
# --The gradient vector g(x_112):
# [[ 4.37884148]
#  [-0.37644748]
#  [ 0.41491152]
#  [ 3.68542234]]
# --The norm of the gradient vector |g(x_112)|: 5.75069168307675
# --The h vector h_112:
# [[-4.37884148]
#  [ 0.37644748]
#  [-0.41491152]
#  [-3.68542234]]
# --The solution vector x_113:
# [[ 1.65821233]
#  [-0.14748676]
#  [ 0.42796068]
#  [ 1.19432474]]
#
# ****************************************************
# --At iteration: 113
# --The gradient vector g(x_113):
# [[ 4.35967981]
#  [-0.37414321]
#  [ 0.41843341]
#  [ 3.67065018]]
# --The norm of the gradient vector |g(x_113)|: 5.726739943300471
# --The h vector h_113:
# [[-4.35967981]
#  [ 0.37414321]
#  [-0.41843341]
#  [-3.67065018]]
# --The solution vector x_114:
# [[ 1.65385265]
#  [-0.14711262]
#  [ 0.42754225]
#  [ 1.19065409]]
#
# ****************************************************
# --At iteration: 114
# --The gradient vector g(x_114):
# [[ 4.34067691]
#  [-0.37189447]
#  [ 0.42172819]
#  [ 3.65589441]]
# --The norm of the gradient vector |g(x_114)|: 5.702911548259143
# --The h vector h_114:
# [[-4.34067691]
#  [ 0.37189447]
#  [-0.42172819]
#  [-3.65589441]]
# --The solution vector x_115:
# [[ 1.64951198]
#  [-0.14674073]
#  [ 0.42712052]
#  [ 1.18699819]]
#
# ****************************************************
# --At iteration: 115
# --The gradient vector g(x_115):
# [[ 4.32182885]
#  [-0.3696985 ]
#  [ 0.42480863]
#  [ 3.64115734]]
# --The norm of the gradient vector |g(x_115)|: 5.679205116304369
# --The h vector h_115:
# [[-4.32182885]
#  [ 0.3696985 ]
#  [-0.42480863]
#  [-3.64115734]]
# --The solution vector x_116:
# [[ 1.64519015]
#  [-0.14637103]
#  [ 0.42669571]
#  [ 1.18335704]]
#
# ****************************************************
# --At iteration: 116
# --The gradient vector g(x_116):
# [[ 4.30313183]
#  [-0.3675527 ]
#  [ 0.42768676]
#  [ 3.62644118]]
# --The norm of the gradient vector |g(x_116)|: 5.655619345690782
# --The h vector h_116:
# [[-4.30313183]
#  [ 0.3675527 ]
#  [-0.42768676]
#  [-3.62644118]]
# --The solution vector x_117:
# [[ 1.64088702]
#  [-0.14600348]
#  [ 0.42626802]
#  [ 1.1797306 ]]
#
# ****************************************************
# --At iteration: 117
# --The gradient vector g(x_117):
# [[ 4.28458224]
#  [-0.36545459]
#  [ 0.43037388]
#  [ 3.61174802]]
# --The norm of the gradient vector |g(x_117)|: 5.632153006852115
# --The h vector h_117:
# [[-4.28458224]
#  [ 0.36545459]
#  [-0.43037388]
#  [-3.61174802]]
# --The solution vector x_118:
# [[ 1.63660243]
#  [-0.14563802]
#  [ 0.42583765]
#  [ 1.17611885]]
#
# ****************************************************
# --At iteration: 118
# --The gradient vector g(x_118):
# [[ 4.2661766 ]
#  [-0.36340184]
#  [ 0.43288069]
#  [ 3.59707985]]
# --The norm of the gradient vector |g(x_118)|: 5.608804935469965
# --The h vector h_118:
# [[-4.2661766 ]
#  [ 0.36340184]
#  [-0.43288069]
#  [-3.59707985]]
# ...
# ****************************************************
# --At iteration: 7916
# --The gradient vector g(x_7916):
# [[ 0.00821328]
#  [-0.00081396]
#  [ 0.00396445]
#  [ 0.00421182]]
# --The norm of the gradient vector |g(x_7916)|: 0.010078528764513529
# --The h vector h_7916:
# [[-0.00821328]
#  [ 0.00081396]
#  [-0.00396445]
#  [-0.00421182]]
# --The solution vector x_7917:
# [[ 0.11526211]
#  [-0.01149107]
#  [ 0.05683214]
#  [ 0.0580041 ]]
#
# ****************************************************
# --At iteration: 7917
# --The gradient vector g(x_7917):
# [[ 0.00821156]
#  [-0.00081379]
#  [ 0.00396364]
#  [ 0.00421092]]
# --The norm of the gradient vector |g(x_7917)|: 0.010076416235882894
# --The h vector h_7917:
# [[-0.00821156]
#  [ 0.00081379]
#  [-0.00396364]
#  [-0.00421092]]
# --The solution vector x_7918:
# [[ 0.1152539 ]
#  [-0.01149026]
#  [ 0.05682817]
#  [ 0.05799989]]
#
# ****************************************************
# --At iteration: 7918
# --The gradient vector g(x_7918):
# [[ 0.00820983]
#  [-0.00081362]
#  [ 0.00396283]
#  [ 0.00421002]]
# --The norm of the gradient vector |g(x_7918)|: 0.010074304436609243
# --The h vector h_7918:
# [[-0.00820983]
#  [ 0.00081362]
#  [-0.00396283]
#  [-0.00421002]]
# --The solution vector x_7919:
# [[ 0.11524569]
#  [-0.01148944]
#  [ 0.05682421]
#  [ 0.05799568]]
#
# ****************************************************
# --At iteration: 7919
# --The gradient vector g(x_7919):
# [[ 0.00820811]
#  [-0.00081345]
#  [ 0.00396201]
#  [ 0.00420912]]
# --The norm of the gradient vector |g(x_7919)|: 0.010072193366343045
# --The h vector h_7919:
# [[-0.00820811]
#  [ 0.00081345]
#  [-0.00396201]
#  [-0.00420912]]
# --The solution vector x_7920:
# [[ 0.11523748]
#  [-0.01148863]
#  [ 0.05682025]
#  [ 0.05799147]]
#
# ****************************************************
# --At iteration: 7920
# --The gradient vector g(x_7920):
# [[ 0.00820639]
#  [-0.00081328]
#  [ 0.0039612 ]
#  [ 0.00420822]]
# --The norm of the gradient vector |g(x_7920)|: 0.010070083024734975
# --The h vector h_7920:
# [[-0.00820639]
#  [ 0.00081328]
#  [-0.0039612 ]
#  [-0.00420822]]
# --The solution vector x_7921:
# [[ 0.11522928]
#  [-0.01148782]
#  [ 0.05681629]
#  [ 0.05798727]]
#
# ****************************************************
# --At iteration: 7921
# --The gradient vector g(x_7921):
# [[ 0.00820467]
#  [-0.00081311]
#  [ 0.00396039]
#  [ 0.00420732]]
# --The norm of the gradient vector |g(x_7921)|: 0.010067973411435935
# --The h vector h_7921:
# [[-0.00820467]
#  [ 0.00081311]
#  [-0.00396039]
#  [-0.00420732]]
# --The solution vector x_7922:
# [[ 0.11522107]
#  [-0.011487  ]
#  [ 0.05681233]
#  [ 0.05798306]]
#
# ****************************************************
# --At iteration: 7922
# --The gradient vector g(x_7922):
# [[ 0.00820296]
#  [-0.00081294]
#  [ 0.00395958]
#  [ 0.00420643]]
# --The norm of the gradient vector |g(x_7922)|: 0.010065864526097035
# --The h vector h_7922:
# [[-0.00820296]
#  [ 0.00081294]
#  [-0.00395958]
#  [-0.00420643]]
# --The solution vector x_7923:
# [[ 0.11521287]
#  [-0.01148619]
#  [ 0.05680837]
#  [ 0.05797885]]
#
# ****************************************************
# --At iteration: 7923
# --The gradient vector g(x_7923):
# [[ 0.00820124]
#  [-0.00081277]
#  [ 0.00395877]
#  [ 0.00420553]]
# --The norm of the gradient vector |g(x_7923)|: 0.010063756368369597
# --The h vector h_7923:
# [[-0.00820124]
#  [ 0.00081277]
#  [-0.00395877]
#  [-0.00420553]]
# --The solution vector x_7924:
# [[ 0.11520467]
#  [-0.01148538]
#  [ 0.05680441]
#  [ 0.05797465]]
#
# ****************************************************
# --At iteration: 7924
# --The gradient vector g(x_7924):
# [[ 0.00819952]
#  [-0.0008126 ]
#  [ 0.00395795]
#  [ 0.00420463]]
# --The norm of the gradient vector |g(x_7924)|: 0.010061648937905157
# --The h vector h_7924:
# [[-0.00819952]
#  [ 0.0008126 ]
#  [-0.00395795]
#  [-0.00420463]]
# --The solution vector x_7925:
# [[ 0.11519647]
#  [-0.01148457]
#  [ 0.05680045]
#  [ 0.05797044]]
#
# ****************************************************
# --At iteration: 7925
# --The gradient vector g(x_7925):
# [[ 0.0081978 ]
#  [-0.00081243]
#  [ 0.00395714]
#  [ 0.00420373]]
# --The norm of the gradient vector |g(x_7925)|: 0.010059542234355467
# --The h vector h_7925:
# [[-0.0081978 ]
#  [ 0.00081243]
#  [-0.00395714]
#  [-0.00420373]]
# --The solution vector x_7926:
# [[ 0.11518827]
#  [-0.01148375]
#  [ 0.05679649]
#  [ 0.05796624]]
#
# ****************************************************
# --At iteration: 7926
# --The gradient vector g(x_7926):
# [[ 0.00819609]
#  [-0.00081226]
#  [ 0.00395633]
#  [ 0.00420284]]
# --The norm of the gradient vector |g(x_7926)|: 0.01005743625737249
# --The h vector h_7926:
# [[-0.00819609]
#  [ 0.00081226]
#  [-0.00395633]
#  [-0.00420284]]
# --The solution vector x_7927:
# [[ 0.11518007]
#  [-0.01148294]
#  [ 0.05679254]
#  [ 0.05796203]]
#
# ****************************************************
# --At iteration: 7927
# --The gradient vector g(x_7927):
# [[ 0.00819437]
#  [-0.0008121 ]
#  [ 0.00395552]
#  [ 0.00420194]]
# --The norm of the gradient vector |g(x_7927)|: 0.010055331006608392
# --The h vector h_7927:
# [[-0.00819437]
#  [ 0.0008121 ]
#  [-0.00395552]
#  [-0.00420194]]
# --The solution vector x_7928:
# [[ 0.11517188]
#  [-0.01148213]
#  [ 0.05678858]
#  [ 0.05795783]]
#
# ****************************************************
# --At iteration: 7928
# --The gradient vector g(x_7928):
# [[ 0.00819266]
#  [-0.00081193]
#  [ 0.00395471]
#  [ 0.00420105]]
# --The norm of the gradient vector |g(x_7928)|: 0.010053226481715574
# --The h vector h_7928:
# [[-0.00819266]
#  [ 0.00081193]
#  [-0.00395471]
#  [-0.00420105]]
# --The solution vector x_7929:
# [[ 0.11516369]
#  [-0.01148132]
#  [ 0.05678463]
#  [ 0.05795363]]
#
# ****************************************************
# --At iteration: 7929
# --The gradient vector g(x_7929):
# [[ 0.00819094]
#  [-0.00081176]
#  [ 0.0039539 ]
#  [ 0.00420015]]
# --The norm of the gradient vector |g(x_7929)|: 0.010051122682346628
# --The h vector h_7929:
# [[-0.00819094]
#  [ 0.00081176]
#  [-0.0039539 ]
#  [-0.00420015]]
# --The solution vector x_7930:
# [[ 0.1151555 ]
#  [-0.01148051]
#  [ 0.05678067]
#  [ 0.05794943]]
#
# ****************************************************
# --At iteration: 7930
# --The gradient vector g(x_7930):
# [[ 0.00818923]
#  [-0.00081159]
#  [ 0.00395309]
#  [ 0.00419926]]
# --The norm of the gradient vector |g(x_7930)|: 0.01004901960815437
# --The h vector h_7930:
# [[-0.00818923]
#  [ 0.00081159]
#  [-0.00395309]
#  [-0.00419926]]
# --The solution vector x_7931:
# [[ 0.11514731]
#  [-0.01147969]
#  [ 0.05677672]
#  [ 0.05794523]]
#
# ****************************************************
# --At iteration: 7931
# --The gradient vector g(x_7931):
# [[ 0.00818751]
#  [-0.00081142]
#  [ 0.00395228]
#  [ 0.00419836]]
# --The norm of the gradient vector |g(x_7931)|: 0.010046917258791825
# --The h vector h_7931:
# [[-0.00818751]
#  [ 0.00081142]
#  [-0.00395228]
#  [-0.00419836]]
# --The solution vector x_7932:
# [[ 0.11513912]
#  [-0.01147888]
#  [ 0.05677277]
#  [ 0.05794103]]
#
# ****************************************************
# --At iteration: 7932
# --The gradient vector g(x_7932):
# [[ 0.0081858 ]
#  [-0.00081125]
#  [ 0.00395147]
#  [ 0.00419747]]
# --The norm of the gradient vector |g(x_7932)|: 0.01004481563391223
# --The h vector h_7932:
# [[-0.0081858 ]
#  [ 0.00081125]
#  [-0.00395147]
#  [-0.00419747]]
# --The solution vector x_7933:
# [[ 0.11513093]
#  [-0.01147807]
#  [ 0.05676881]
#  [ 0.05793684]]
#
# ****************************************************
# --At iteration: 7933
# --The gradient vector g(x_7933):
# [[ 0.00818409]
#  [-0.00081108]
#  [ 0.00395066]
#  [ 0.00419657]]
# --The norm of the gradient vector |g(x_7933)|: 0.01004271473316903
# --The h vector h_7933:
# [[-0.00818409]
#  [ 0.00081108]
#  [-0.00395066]
#  [-0.00419657]]
# --The solution vector x_7934:
# [[ 0.11512275]
#  [-0.01147726]
#  [ 0.05676486]
#  [ 0.05793264]]
#
# ****************************************************
# --At iteration: 7934
# --The gradient vector g(x_7934):
# [[ 0.00818238]
#  [-0.00081091]
#  [ 0.00394986]
#  [ 0.00419568]]
# --The norm of the gradient vector |g(x_7934)|: 0.010040614556215893
# --The h vector h_7934:
# [[-0.00818238]
#  [ 0.00081091]
#  [-0.00394986]
#  [-0.00419568]]
# --The solution vector x_7935:
# [[ 0.11511457]
#  [-0.01147645]
#  [ 0.05676091]
#  [ 0.05792844]]
#
# ****************************************************
# --At iteration: 7935
# --The gradient vector g(x_7935):
# [[ 0.00818067]
#  [-0.00081075]
#  [ 0.00394905]
#  [ 0.00419478]]
# --The norm of the gradient vector |g(x_7935)|: 0.010038515102706683
# --The h vector h_7935:
# [[-0.00818067]
#  [ 0.00081075]
#  [-0.00394905]
#  [-0.00419478]]
# --The solution vector x_7936:
# [[ 0.11510639]
#  [-0.01147564]
#  [ 0.05675696]
#  [ 0.05792425]]
#
# ****************************************************
# --At iteration: 7936
# --The gradient vector g(x_7936):
# [[ 0.00817895]
#  [-0.00081058]
#  [ 0.00394824]
#  [ 0.00419389]]
# --The norm of the gradient vector |g(x_7936)|: 0.010036416372295489
# --The h vector h_7936:
# [[-0.00817895]
#  [ 0.00081058]
#  [-0.00394824]
#  [-0.00419389]]
# --The solution vector x_7937:
# [[ 0.11509821]
#  [-0.01147483]
#  [ 0.05675302]
#  [ 0.05792006]]
#
# ****************************************************
# --At iteration: 7937
# --The gradient vector g(x_7937):
# [[ 0.00817725]
#  [-0.00081041]
#  [ 0.00394743]
#  [ 0.004193  ]]
# --The norm of the gradient vector |g(x_7937)|: 0.010034318364636604
# --The h vector h_7937:
# [[-0.00817725]
#  [ 0.00081041]
#  [-0.00394743]
#  [-0.004193  ]]
# --The solution vector x_7938:
# [[ 0.11509003]
#  [-0.01147402]
#  [ 0.05674907]
#  [ 0.05791586]]
#
# ****************************************************
# --At iteration: 7938
# --The gradient vector g(x_7938):
# [[ 0.00817554]
#  [-0.00081024]
#  [ 0.00394662]
#  [ 0.00419211]]
# --The norm of the gradient vector |g(x_7938)|: 0.010032221079384535
# --The h vector h_7938:
# [[-0.00817554]
#  [ 0.00081024]
#  [-0.00394662]
#  [-0.00419211]]
# --The solution vector x_7939:
# [[ 0.11508185]
#  [-0.01147321]
#  [ 0.05674512]
#  [ 0.05791167]]
#
# ****************************************************
# --At iteration: 7939
# --The gradient vector g(x_7939):
# [[ 0.00817383]
#  [-0.00081007]
#  [ 0.00394582]
#  [ 0.00419121]]
# --The norm of the gradient vector |g(x_7939)|: 0.010030124516193997
# --The h vector h_7939:
# [[-0.00817383]
#  [ 0.00081007]
#  [-0.00394582]
#  [-0.00419121]]
# --The solution vector x_7940:
# [[ 0.11507368]
#  [-0.0114724 ]
#  [ 0.05674118]
#  [ 0.05790748]]
#
# ****************************************************
# --At iteration: 7940
# --The gradient vector g(x_7940):
# [[ 0.00817212]
#  [-0.0008099 ]
#  [ 0.00394501]
#  [ 0.00419032]]
# --The norm of the gradient vector |g(x_7940)|: 0.010028028674719915
# --The h vector h_7940:
# [[-0.00817212]
#  [ 0.0008099 ]
#  [-0.00394501]
#  [-0.00419032]]
# --The solution vector x_7941:
# [[ 0.11506551]
#  [-0.01147159]
#  [ 0.05673723]
#  [ 0.05790329]]
#
# ****************************************************
# --At iteration: 7941
# --The gradient vector g(x_7941):
# [[ 0.00817041]
#  [-0.00080974]
#  [ 0.0039442 ]
#  [ 0.00418943]]
# --The norm of the gradient vector |g(x_7941)|: 0.01002593355461743
# --The h vector h_7941:
# [[-0.00817041]
#  [ 0.00080974]
#  [-0.0039442 ]
#  [-0.00418943]]
# --The solution vector x_7942:
# [[ 0.11505734]
#  [-0.01147078]
#  [ 0.05673329]
#  [ 0.0578991 ]]
#
# ****************************************************
# --At iteration: 7942
# --The gradient vector g(x_7942):
# [[ 0.0081687 ]
#  [-0.00080957]
#  [ 0.0039434 ]
#  [ 0.00418854]]
# --The norm of the gradient vector |g(x_7942)|: 0.010023839155541892
# --The h vector h_7942:
# [[-0.0081687 ]
#  [ 0.00080957]
#  [-0.0039434 ]
#  [-0.00418854]]
# --The solution vector x_7943:
# [[ 0.11504917]
#  [-0.01146997]
#  [ 0.05672934]
#  [ 0.05789491]]
#
# ****************************************************
# --At iteration: 7943
# --The gradient vector g(x_7943):
# [[ 0.008167  ]
#  [-0.0008094 ]
#  [ 0.00394259]
#  [ 0.00418765]]
# --The norm of the gradient vector |g(x_7943)|: 0.010021745477148854
# --The h vector h_7943:
# [[-0.008167  ]
#  [ 0.0008094 ]
#  [-0.00394259]
#  [-0.00418765]]
# --The solution vector x_7944:
# [[ 0.115041  ]
#  [-0.01146916]
#  [ 0.0567254 ]
#  [ 0.05789072]]
#
# ****************************************************
# --At iteration: 7944
# --The gradient vector g(x_7944):
# [[ 0.00816529]
#  [-0.00080923]
#  [ 0.00394178]
#  [ 0.00418676]]
# --The norm of the gradient vector |g(x_7944)|: 0.010019652519094091
# --The h vector h_7944:
# [[-0.00816529]
#  [ 0.00080923]
#  [-0.00394178]
#  [-0.00418676]]
# --The solution vector x_7945:
# [[ 0.11503284]
#  [-0.01146835]
#  [ 0.05672146]
#  [ 0.05788654]]
#
# ****************************************************
# --At iteration: 7945
# --The gradient vector g(x_7945):
# [[ 0.00816359]
#  [-0.00080906]
#  [ 0.00394098]
#  [ 0.00418587]]
# --The norm of the gradient vector |g(x_7945)|: 0.010017560281033577
# --The h vector h_7945:
# [[-0.00816359]
#  [ 0.00080906]
#  [-0.00394098]
#  [-0.00418587]]
# --The solution vector x_7946:
# [[ 0.11502467]
#  [-0.01146754]
#  [ 0.05671752]
#  [ 0.05788235]]
#
# ****************************************************
# --At iteration: 7946
# --The gradient vector g(x_7946):
# [[ 0.00816188]
#  [-0.00080889]
#  [ 0.00394017]
#  [ 0.00418498]]
# --The norm of the gradient vector |g(x_7946)|: 0.010015468762623506
# --The h vector h_7946:
# [[-0.00816188]
#  [ 0.00080889]
#  [-0.00394017]
#  [-0.00418498]]
# --The solution vector x_7947:
# [[ 0.11501651]
#  [-0.01146673]
#  [ 0.05671358]
#  [ 0.05787817]]
#
# ****************************************************
# --At iteration: 7947
# --The gradient vector g(x_7947):
# [[ 0.00816018]
#  [-0.00080873]
#  [ 0.00393937]
#  [ 0.00418409]]
# --The norm of the gradient vector |g(x_7947)|: 0.010013377963520271
# --The h vector h_7947:
# [[-0.00816018]
#  [ 0.00080873]
#  [-0.00393937]
#  [-0.00418409]]
# --The solution vector x_7948:
# [[ 0.11500835]
#  [-0.01146592]
#  [ 0.05670964]
#  [ 0.05787398]]
#
# ****************************************************
# --At iteration: 7948
# --The gradient vector g(x_7948):
# [[ 0.00815847]
#  [-0.00080856]
#  [ 0.00393856]
#  [ 0.0041832 ]]
# --The norm of the gradient vector |g(x_7948)|: 0.01001128788338048
# --The h vector h_7948:
# [[-0.00815847]
#  [ 0.00080856]
#  [-0.00393856]
#  [-0.0041832 ]]
# --The solution vector x_7949:
# [[ 0.11500019]
#  [-0.01146511]
#  [ 0.0567057 ]
#  [ 0.0578698 ]]
#
# ****************************************************
# --At iteration: 7949
# --The gradient vector g(x_7949):
# [[ 0.00815677]
#  [-0.00080839]
#  [ 0.00393776]
#  [ 0.00418231]]
# --The norm of the gradient vector |g(x_7949)|: 0.010009198521860956
# --The h vector h_7949:
# [[-0.00815677]
#  [ 0.00080839]
#  [-0.00393776]
#  [-0.00418231]]
# --The solution vector x_7950:
# [[ 0.11499204]
#  [-0.01146431]
#  [ 0.05670176]
#  [ 0.05786562]]
#
# ****************************************************
# --At iteration: 7950
# --The gradient vector g(x_7950):
# [[ 0.00815507]
#  [-0.00080822]
#  [ 0.00393695]
#  [ 0.00418142]]
# --The norm of the gradient vector |g(x_7950)|: 0.010007109878618718
# --The h vector h_7950:
# [[-0.00815507]
#  [ 0.00080822]
#  [-0.00393695]
#  [-0.00418142]]
# --The solution vector x_7951:
# [[ 0.11498388]
#  [-0.0114635 ]
#  [ 0.05669783]
#  [ 0.05786143]]
#
# ****************************************************
# --At iteration: 7951
# --The gradient vector g(x_7951):
# [[ 0.00815337]
#  [-0.00080806]
#  [ 0.00393615]
#  [ 0.00418053]]
# --The norm of the gradient vector |g(x_7951)|: 0.010005021953311008
# --The h vector h_7951:
# [[-0.00815337]
#  [ 0.00080806]
#  [-0.00393615]
#  [-0.00418053]]
# --The solution vector x_7952:
# [[ 0.11497573]
#  [-0.01146269]
#  [ 0.05669389]
#  [ 0.05785725]]
#
# ****************************************************
# --At iteration: 7952
# --The gradient vector g(x_7952):
# [[ 0.00815167]
#  [-0.00080789]
#  [ 0.00393535]
#  [ 0.00417964]]
# --The norm of the gradient vector |g(x_7952)|: 0.010002934745595262
# --The h vector h_7952:
# [[-0.00815167]
#  [ 0.00080789]
#  [-0.00393535]
#  [-0.00417964]]
# --The solution vector x_7953:
# [[ 0.11496758]
#  [-0.01146188]
#  [ 0.05668995]
#  [ 0.05785307]]
#
# ****************************************************
# --At iteration: 7953
# --The gradient vector g(x_7953):
# [[ 0.00814997]
#  [-0.00080772]
#  [ 0.00393454]
#  [ 0.00417875]]
# --The norm of the gradient vector |g(x_7953)|: 0.01000084825512914
# --The h vector h_7953:
# [[-0.00814997]
#  [ 0.00080772]
#  [-0.00393454]
#  [-0.00417875]]
# --The solution vector x_7954:
# [[ 0.11495943]
#  [-0.01146107]
#  [ 0.05668602]
#  [ 0.0578489 ]]
#
# ****************************************************
# --At iteration: 7954
# --The gradient vector g(x_7954):
# [[ 0.00814827]
#  [-0.00080755]
#  [ 0.00393374]
#  [ 0.00417787]]
# --The norm of the gradient vector |g(x_7954)|: 0.009998762481570502

# %% [markdown]
# As we see, our iterations are 4500, and our gradient vector is as follows:
# *x* =
# [ 0.00814827]
#  [-0.00080755]
#  [ 0.00393374]
#  [ 0.00417787]

# %% [markdown]
# For part 2 of this question, what would happen if we were to change the alpha value to 0.1? Would the gradient descent still converge?
# The answer is no it would not because the polynomial contains high degree polynomial terms, which mean it's rapidly growing. Along with it being nonlinear, this makes for a function that will grow very fast and big.
# With a large alpha like 0.1, it will overshoot our minimum and will actually diverge instead of converge. Thus, no it will not converge.
