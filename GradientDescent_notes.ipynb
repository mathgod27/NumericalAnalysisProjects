# %% [markdown]
# <a href="https://colab.research.google.com/github/mathgod27/NumericalAnalysisProjects/blob/main/GradientDescent_notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import the libraries
import numpy as np
import math

# %% [markdown]
# ## Implement its gradient vector, which is an exercise presented on Slide 39 of Topic 3.1
#
# ![gradient1.PNG](data:image/png;base64,...)

# %%
## a function returns the Gradient vector at the input vector x_i
## note: the expression of each element in the Gradient vector is hard-coded based on the formula presented above, which is also given on Slide 40 of Topic 3.1
def getGradientVector(x_i):
  g = np.zeros((3,1))
  g[0] = 4 * (x_i[0]-4) *(x_i[0]-4) *(x_i[0]-4)
  g[1] = 2 * (x_i[1]-3)
  g[2] = 8 * (x_i[2] + 5)
  return g

# a simple function returns the norm of an input vector
def getNorm(v):
  return math.sqrt(v[0]*v[0]+v[1]*v[1]+v[2]*v[2])

# %% [markdown]
# ## Perform the Gradient Descent Method for minimizing the nonlinear function
#
# ![gradient2.PNG](data:image/png;base64,...)

# %%
## set an initial guess
x_0 = np.array([[4], [2], [-1]])
print(f"--The initial guess x0: ")
print(x_0)

## set a threshold value for getting a good solution
thresh = 0.01

## set step length
alpha = 0.1

x_i = x_0
count = 0
while True:
  print('****************************************************')
  print(f'--At iteration: {count}')

  ## compute the gradient vector at x_i
  g = getGradientVector(x_i)
  print(f"--The gradient vector g(x_{count}): ")
  print(g)

  ## compute the norm of the gradient vector at x_i
  normOfGradient = getNorm(g)
  print(f"--The norm of the gradient vector |g(x_{count})|: {normOfGradient}")

  ## check if converged; if true, then stop; continue otherwise
  if normOfGradient <= thresh:
    break


  ## get h=-g
  h_i = -1*g
  print(f"--The h vector h_{count}: ")
  print(h_i)

  ## get the new solution point
  x_i_plus1 = x_i + alpha * h_i
  print(f"--The solution vector x_{count+1}: ")
  print(x_i_plus1)

  x_i = x_i_plus1
  count = count + 1
  print()
# Out:
# --The initial guess x0:
# [[ 4]
#  [ 2]
#  [-1]]
# ****************************************************
# --At iteration: 0
# --The gradient vector g(x_0):
# [[ 0.]
#  [-2.]
#  [32.]]
# --The norm of the gradient vector |g(x_0)|: 32.0624390837628
# --The h vector h_0:
# [[ -0.]
#  [  2.]
#  [-32.]]
# --The solution vector x_1:
# [[ 4. ]
#  [ 2.2]
#  [-4.2]]
#
# ****************************************************
# --At iteration: 1
# --The gradient vector g(x_1):
# [[ 0. ]
#  [-1.6]
#  [ 6.4]]
# --The norm of the gradient vector |g(x_1)|: 6.596969000988255
# --The h vector h_1:
# [[-0. ]
#  [ 1.6]
#  [-6.4]]
# --The solution vector x_2:
# [[ 4.  ]
#  [ 2.36]
#  [-4.84]]
#
# ****************************************************
# --At iteration: 2
# --The gradient vector g(x_2):
# [[ 0.  ]
#  [-1.28]
#  [ 1.28]]
# --The norm of the gradient vector |g(x_2)|: 1.8101933598375621
# --The h vector h_2:
# [[-0.  ]
#  [ 1.28]
#  [-1.28]]
# --The solution vector x_3:
# [[ 4.   ]
#  [ 2.488]
#  [-4.968]]
#
# ****************************************************
# --At iteration: 3
# --The gradient vector g(x_3):
# [[ 0.   ]
#  [-1.024]
#  [ 0.256]]
# --The norm of the gradient vector |g(x_3)|: 1.0555150401581204
# --The h vector h_3:
# [[-0.   ]
#  [ 1.024]
#  [-0.256]]
# --The solution vector x_4:
# [[ 4.    ]
#  [ 2.5904]
#  [-4.9936]]
#
# ****************************************************
# --At iteration: 4
# --The gradient vector g(x_4):
# [[ 0.    ]
#  [-0.8192]
#  [ 0.0512]]
# --The norm of the gradient vector |g(x_4)|: 0.8207984405443272
# --The h vector h_4:
# [[-0.    ]
#  [ 0.8192]
#  [-0.0512]]
# --The solution vector x_5:
# [[ 4.     ]
#  [ 2.67232]
#  [-4.99872]]
#
# ****************************************************
# --At iteration: 5
# --The gradient vector g(x_5):
# [[ 0.     ]
#  [-0.65536]
#  [ 0.01024]]
# --The norm of the gradient vector |g(x_5)|: 0.6554399951177834
# --The h vector h_5:
# [[-0.     ]
#  [ 0.65536]
#  [-0.01024]]
# --The solution vector x_6:
# [[ 4.      ]
#  [ 2.737856]
#  [-4.999744]]
#
# ****************************************************
# --At iteration: 6
# --The gradient vector g(x_6):
# [[ 0.      ]
#  [-0.524288]
#  [ 0.002048]]
# --The norm of the gradient vector |g(x_6)|: 0.5242919999847416
# --The h vector h_6:
# [[-0.      ]
#  [ 0.524288]
#  [-0.002048]]
# --The solution vector x_7:
# [[ 4.       ]
#  [ 2.7902848]
#  [-4.9999488]]
#
# ****************************************************
# --At iteration: 7
# --The gradient vector g(x_7):
# [[ 0.000000e+00]
#  [-4.194304e-01]
#  [ 4.096000e-04]]
# --The norm of the gradient vector |g(x_7)|: 0.41943059999995275
# --The h vector h_7:
# [[-0.000000e+00]
#  [ 4.194304e-01]
#  [-4.096000e-04]]
# --The solution vector x_8:
# [[ 4.        ]
#  [ 2.83222784]
#  [-4.99998976]]
#
# ****************************************************
# --At iteration: 8
# --The gradient vector g(x_8):
# [[ 0.0000000e+00]
#  [-3.3554432e-01]
#  [ 8.1920000e-05]]
# --The norm of the gradient vector |g(x_8)|: 0.3355443300000002
# --The h vector h_8:
# [[-0.0000000e+00]
#  [ 3.3554432e-01]
#  [-8.1920000e-05]]
# --The solution vector x_9:
# [[ 4.        ]
#  [ 2.86578227]
#  [-4.99999795]]
#
# ****************************************************
# --At iteration: 9
# --The gradient vector g(x_9):
# [[ 0.00000000e+00]
#  [-2.68435456e-01]
#  [ 1.63840000e-05]]
# --The norm of the gradient vector |g(x_9)|: 0.2684354565000006
# --The h vector h_9:
# [[-0.00000000e+00]
#  [ 2.68435456e-01]
#  [-1.63840000e-05]]
# --The solution vector x_10:
# [[ 4.        ]
#  [ 2.89262582]
#  [-4.99999959]]
#
# ****************************************************
# --At iteration: 10
# --The gradient vector g(x_10):
# [[ 0.00000000e+00]
#  [-2.14748365e-01]
#  [ 3.27680000e-06]]
# --The norm of the gradient vector |g(x_10)|: 0.21474836482500015
# --The h vector h_10:
# [[-0.00000000e+00]
#  [ 2.14748365e-01]
#  [-3.27680000e-06]]
# --The solution vector x_11:
# [[ 4.        ]
#  [ 2.91410065]
#  [-4.99999992]]
#
# ****************************************************
# --At iteration: 11
# --The gradient vector g(x_11):
# [[ 0.00000000e+00]
#  [-1.71798692e-01]
#  [ 6.55359997e-07]]
# --The norm of the gradient vector |g(x_11)|: 0.1717986918412503
# --The h vector h_11:
# [[-0.00000000e+00]
#  [ 1.71798692e-01]
#  [-6.55359997e-07]]
# --The solution vector x_12:
# [[ 4.        ]
#  [ 2.93128052]
#  [-4.99999998]]
#
# ****************************************************
# --At iteration: 12
# --The gradient vector g(x_12):
# [[ 0.00000000e+00]
#  [-1.37438953e-01]
#  [ 1.31071999e-07]]
# --The norm of the gradient vector |g(x_12)|: 0.13743895347206292
# --The h vector h_12:
# [[-0.00000000e+00]
#  [ 1.37438953e-01]
#  [-1.31071999e-07]]
# --The solution vector x_13:
# [[ 4.        ]
#  [ 2.94502442]
#  [-5.        ]]
#
# ****************************************************
# --At iteration: 13
# --The gradient vector g(x_13):
# [[ 0.00000000e+00]
#  [-1.09951163e-01]
#  [ 2.62144013e-08]]
# --The norm of the gradient vector |g(x_13)|: 0.1099511627776031
# --The h vector h_13:
# [[-0.00000000e+00]
#  [ 1.09951163e-01]
#  [-2.62144013e-08]]
# --The solution vector x_14:
# [[ 4.        ]
#  [ 2.95601953]
#  [-5.        ]]
#
# ****************************************************
# --At iteration: 14
# --The gradient vector g(x_14):
# [[ 0.00000000e+00]
#  [-8.79609302e-02]
#  [ 5.24288168e-09]]
# --The norm of the gradient vector |g(x_14)|: 0.08796093022207978
# --The h vector h_14:
# [[-0.00000000e+00]
#  [ 8.79609302e-02]
#  [-5.24288168e-09]]
# --The solution vector x_15:
# [[ 4.        ]
#  [ 2.96481563]
#  [-5.        ]]
#
# ****************************************************
# --At iteration: 15
# --The gradient vector g(x_15):
# [[ 0.00000000e+00]
#  [-7.03687442e-02]
#  [ 1.04857634e-09]]
# --The norm of the gradient vector |g(x_15)|: 0.07036874417766371
# --The h vector h_15:
# [[-0.00000000e+00]
#  [ 7.03687442e-02]
#  [-1.04857634e-09]]
# --The solution vector x_16:
# [[ 4.       ]
#  [ 2.9718525]
#  [-5.       ]]
#
# ****************************************************
# --At iteration: 16
# --The gradient vector g(x_16):
# [[ 0.00000000e+00]
#  [-5.62949953e-02]
#  [ 2.09716688e-10]]
# --The norm of the gradient vector |g(x_16)|: 0.05629499534213078
# --The h vector h_16:
# [[-0.00000000e+00]
#  [ 5.62949953e-02]
#  [-2.09716688e-10]]
# --The solution vector x_17:
# [[ 4.      ]
#  [ 2.977482]
#  [-5.      ]]
#
# ****************************************************
# --At iteration: 17
# --The gradient vector g(x_17):
# [[ 0.00000000e+00]
#  [-4.50359963e-02]
#  [ 4.19433377e-11]]
# --The norm of the gradient vector |g(x_17)|: 0.045035996273704804
# --The h vector h_17:
# [[-0.00000000e+00]
#  [ 4.50359963e-02]
#  [-4.19433377e-11]]
# --The solution vector x_18:
# [[ 4.       ]
#  [ 2.9819856]
#  [-5.       ]]
#
# ****************************************************
# --At iteration: 18
# --The gradient vector g(x_18):
# [[ 0.00000000e+00]
#  [-3.60287970e-02]
#  [ 8.39150971e-12]]
# --The norm of the gradient vector |g(x_18)|: 0.036028797018963665
# --The h vector h_18:
# [[-0.00000000e+00]
#  [ 3.60287970e-02]
#  [-8.39150971e-12]]
# --The solution vector x_19:
# [[ 4.        ]
#  [ 2.98558848]
#  [-5.        ]]
#
# ****************************************************
# --At iteration: 19
# --The gradient vector g(x_19):
# [[ 0.00000000e+00]
#  [-2.88230376e-02]
#  [ 1.67688086e-12]]
# --The norm of the gradient vector |g(x_19)|: 0.028823037615170577
# --The h vector h_19:
# [[-0.00000000e+00]
#  [ 2.88230376e-02]
#  [-1.67688086e-12]]
# --The solution vector x_20:
# [[ 4.        ]
#  [ 2.98847078]
#  [-5.        ]]
#
# ****************************************************
# --At iteration: 20
# --The gradient vector g(x_20):
# [[ 0.00000000e+00]
#  [-2.30584301e-02]
#  [ 3.33955086e-13]]
# --The norm of the gradient vector |g(x_20)|: 0.023058430092136817
# --The h vector h_20:
# [[-0.00000000e+00]
#  [ 2.30584301e-02]
#  [-3.33955086e-13]]
# --The solution vector x_21:
# [[ 4.        ]
#  [ 2.99077663]
#  [-5.        ]]
#
# ****************************************************
# --At iteration: 21
# --The gradient vector g(x_21):
# [[ 0.00000000e+00]
#  [-1.84467441e-02]
#  [ 6.39488462e-14]]
# --The norm of the gradient vector |g(x_21)|: 0.018446744073709276
# --The h vector h_21:
# [[-0.00000000e+00]
#  [ 1.84467441e-02]
#  [-6.39488462e-14]]
# --The solution vector x_22:
# [[ 4.       ]
#  [ 2.9926213]
#  [-5.       ]]
#
# ****************************************************
# --At iteration: 22
# --The gradient vector g(x_22):
# [[ 0.00000000e+00]
#  [-1.47573953e-02]
#  [ 1.42108547e-14]]
# --The norm of the gradient vector |g(x_22)|: 0.014757395258967243
# --The h vector h_22:
# [[-0.00000000e+00]
#  [ 1.47573953e-02]
#  [-1.42108547e-14]]
# --The solution vector x_23:
# [[ 4.        ]
#  [ 2.99409704]
#  [-5.        ]]
#
# ****************************************************
# --At iteration: 23
# --The gradient vector g(x_23):
# [[ 0.        ]
#  [-0.01180592]
#  [ 0.        ]]
# --The norm of the gradient vector |g(x_23)|: 0.011805916207173972
# --The h vector h_23:
# [[-0.        ]
#  [ 0.01180592]
#  [-0.        ]]
# --The solution vector x_24:
# [[ 4.        ]
#  [ 2.99527763]
#  [-5.        ]]
#
# ****************************************************
# --At iteration: 24
# --The gradient vector g(x_24):
# [[ 0.        ]
#  [-0.00944473]
#  [ 0.        ]]
# --The norm of the gradient vector |g(x_24)|: 0.009444732965739
